# %% [markdown]
# # Text Classification Using Word2Vec and AverageWord2Vec

# %%
import gensim
from gensim.models import Word2Vec,KeyedVectors
from gensim.utils import simple_preprocess

import numpy as np
import pandas as pd

import chardet

import re
import nltk
nltk.download('stopwrods')
from nltk.stem import WordNetLemmatizer
from nltk import sent_tokenize

from tqdm import tqdm
# Out:
# [nltk_data] Error loading stopwrods: Package 'stopwrods' not found in
# [nltk_data]     index

# %%
# import gensim.downloader as api
# wv=api.load('word2vec-google-news-300')
# vec_king=wv['king']

# %%
# vec_king.shape

# %%
# Detect the encoding
with open('spam.csv', 'rb') as f:
    result = chardet.detect(f.read())
print(result['encoding'])

# Use the detected encoding
messages = pd.read_csv("spam.csv", encoding=result['encoding'])
# Out:
# Windows-1252

# %%
messages=messages.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'],axis=1)
messages=messages.rename(columns={'v1':'label','v2':'message'})

# %%
lemmatizer=WordNetLemmatizer()

# %%
corpus=[]
for i in range(0,len(messages)):
    review=re.sub('[^a-zA-Z]',' ',messages['message'][i])
    review=review.lower()
    review=review.split()
    review=[lemmatizer.lemmatize(word) for word in review]
    review=' '.join(review)
    corpus.append(review)

# %%
words=[]
for sent in corpus:
    sent_token=sent_tokenize(sent)
    for sent in sent_token:
        words.append(simple_preprocess(sent))

# %%
words
# Out:
# [['go',
#   'until',
#   'jurong',
#   'point',
#   'crazy',
#   'available',
#   'only',
#   'in',
#   'bugis',
#   'great',
#   'world',
#   'la',
#   'buffet',
#   'cine',
#   'there',
#   'got',
#   'amore',
#   'wat'],
#  ['ok', 'lar', 'joking', 'wif', 'oni'],
#  ['free',
#   'entry',
#   'in',
#   'wkly',
#   'comp',
#   'to',
#   'win',
#   'fa',
#   'cup',
#   'final',
#   'tkts',
#   'st',
#   'may',
#   'text',
#   'fa',
#   'to',
#   'to',
#   'receive',
#   'entry',
#   'question',
#   'std',
#   'txt',
#   'rate',
#   'apply',
#   'over'],
#  ['dun', 'say', 'so', 'early', 'hor', 'already', 'then', 'say'],
#  ['nah',
#   'don',
#   'think',
#   'he',
#   'go',
#   'to',
#   'usf',
#   'he',
#   'life',
#   'around',
#   'here',
#   'though'],
#  ['freemsg',
#   'hey',
#   'there',
#   'darling',
#   'it',
#   'been',
#   'week',
#   'now',
#   'and',
#   'no',
#   'word',
#   'back',
#   'like',
#   'some',
#   'fun',
#   'you',
#   'up',
#   'for',
#   'it',
#   'still',
#   'tb',
#   'ok',
#   'xxx',
#   'std',
#   'chgs',
#   'to',
#   'send',
#   'to',
#   'rcv'],
#  ['even',
#   'my',
#   'brother',
#   'is',
#   'not',
#   'like',
#   'to',
#   'speak',
#   'with',
#   'me',
#   'they',
#   'treat',
#   'me',
#   'like',
#   'aid',
#   'patent'],
#  ['per',
#   'your',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'ha',
#   'been',
#   'set',
#   'your',
#   'callertune',
#   'for',
#   'all',
#   'caller',
#   'press',
#   'to',
#   'copy',
#   'your',
#   'friend',
#   'callertune'],
#  ['winner',
#   'valued',
#   'network',
#   'customer',
#   'you',
#   'have',
#   'been',
#   'selected',
#   'to',
#   'receivea',
#   'prize',
#   'reward',
#   'to',
#   'claim',
#   'call',
#   'claim',
#   'code',
#   'kl',
#   'valid',
#   'hour',
#   'only'],
#  ['had',
#   'your',
#   'mobile',
#   'month',
#   'or',
#   'more',
#   'entitled',
#   'to',
#   'update',
#   'to',
#   'the',
#   'latest',
#   'colour',
#   'mobile',
#   'with',
#   'camera',
#   'for',
#   'free',
#   'call',
#   'the',
#   'mobile',
#   'update',
#   'co',
#   'free',
#   'on'],
#  ['gonna',
#   'be',
#   'home',
#   'soon',
#   'and',
#   'don',
#   'want',
#   'to',
#   'talk',
#   'about',
#   'this',
#   'stuff',
#   'anymore',
#   'tonight',
#   've',
#   'cried',
#   'enough',
#   'today'],
#  ['six',
#   'chance',
#   'to',
#   'win',
#   'cash',
#   'from',
#   'to',
#   'pound',
#   'txt',
#   'csh',
#   'and',
#   'send',
#   'to',
#   'cost',
#   'day',
#   'day',
#   'tsandcs',
#   'apply',
#   'reply',
#   'hl',
#   'info'],
#  ['urgent',
#   'you',
#   'have',
#   'won',
#   'week',
#   'free',
#   'membership',
#   'in',
#   'our',
#   'prize',
#   'jackpot',
#   'txt',
#   'the',
#   'word',
#   'claim',
#   'to',
#   'no',
#   'www',
#   'dbuk',
#   'net',
#   'lccltd',
#   'pobox',
#   'ldnw',
#   'rw'],
#  ['ve',
#   'been',
#   'searching',
#   'for',
#   'the',
#   'right',
#   'word',
#   'to',
#   'thank',
#   'you',
#   'for',
#   'this',
#   'breather',
#   'promise',
#   'wont',
#   'take',
#   'your',
#   'help',
#   'for',
#   'granted',
#   'and',
#   'will',
#   'fulfil',
#   'my',
#   'promise',
#   'you',
#   'have',
#   'been',
#   'wonderful',
#   'and',
#   'blessing',
#   'at',
#   'all',
#   'time'],
#  ['have', 'date', 'on', 'sunday', 'with', 'will'],
#  ['to',
#   'use',
#   'your',
#   'credit',
#   'click',
#   'the',
#   'wap',
#   'link',
#   'in',
#   'the',
#   'next',
#   'txt',
#   'message',
#   'or',
#   'click',
#   'here',
#   'http',
#   'wap',
#   'com',
#   'qjkgighjjgcbl'],
#  ['oh', 'watching', 'here'],
#  ['eh',
#   'remember',
#   'how',
#   'spell',
#   'his',
#   'name',
#   'yes',
#   'did',
#   'he',
#   'naughty',
#   'make',
#   'until',
#   'wet'],
#  ['fine',
#   'if',
#   'that',
#   'the',
#   'way',
#   'feel',
#   'that',
#   'the',
#   'way',
#   'it',
#   'gota'],
#  ['england',
#   'macedonia',
#   'dont',
#   'miss',
#   'the',
#   'goal',
#   'team',
#   'news',
#   'txt',
#   'ur',
#   'national',
#   'team',
#   'to',
#   'eg',
#   'england',
#   'to',
#   'try',
#   'wale',
#   'scotland',
#   'txt',
#   'poboxox',
#   'wq'],
#  ['is', 'that', 'seriously', 'how', 'you', 'spell', 'his', 'name'],
#  ['going', 'to', 'try', 'for', 'month', 'ha', 'ha', 'only', 'joking'],
#  ['so', 'pay', 'first', 'lar', 'then', 'when', 'is', 'da', 'stock', 'comin'],
#  ['aft',
#   'finish',
#   'my',
#   'lunch',
#   'then',
#   'go',
#   'str',
#   'down',
#   'lor',
#   'ard',
#   'smth',
#   'lor',
#   'finish',
#   'ur',
#   'lunch',
#   'already'],
#  ['ffffffffff',
#   'alright',
#   'no',
#   'way',
#   'can',
#   'meet',
#   'up',
#   'with',
#   'you',
#   'sooner'],
#  ['just',
#   'forced',
#   'myself',
#   'to',
#   'eat',
#   'slice',
#   'really',
#   'not',
#   'hungry',
#   'tho',
#   'this',
#   'suck',
#   'mark',
#   'is',
#   'getting',
#   'worried',
#   'he',
#   'know',
#   'sick',
#   'when',
#   'turn',
#   'down',
#   'pizza',
#   'lol'],
#  ['lol', 'your', 'always', 'so', 'convincing'],
#  ['did',
#   'you',
#   'catch',
#   'the',
#   'bus',
#   'are',
#   'you',
#   'frying',
#   'an',
#   'egg',
#   'did',
#   'you',
#   'make',
#   'tea',
#   'are',
#   'you',
#   'eating',
#   'your',
#   'mom',
#   'left',
#   'over',
#   'dinner',
#   'do',
#   'you',
#   'feel',
#   'my',
#   'love'],
#  ['back',
#   'amp',
#   'we',
#   're',
#   'packing',
#   'the',
#   'car',
#   'now',
#   'll',
#   'let',
#   'you',
#   'know',
#   'if',
#   'there',
#   'room'],
#  ['ahhh',
#   'work',
#   'vaguely',
#   'remember',
#   'that',
#   'what',
#   'doe',
#   'it',
#   'feel',
#   'like',
#   'lol'],
#  ['wait',
#   'that',
#   'still',
#   'not',
#   'all',
#   'that',
#   'clear',
#   'were',
#   'you',
#   'not',
#   'sure',
#   'about',
#   'me',
#   'being',
#   'sarcastic',
#   'or',
#   'that',
#   'that',
#   'why',
#   'doesn',
#   'want',
#   'to',
#   'live',
#   'with'],
#  ['yeah',
#   'he',
#   'got',
#   'in',
#   'at',
#   'and',
#   'wa',
#   'apologetic',
#   'had',
#   'fallen',
#   'out',
#   'and',
#   'she',
#   'wa',
#   'actin',
#   'like',
#   'spoilt',
#   'child',
#   'and',
#   'he',
#   'got',
#   'caught',
#   'up',
#   'in',
#   'that',
#   'till',
#   'but',
#   'we',
#   'won',
#   'go',
#   'there',
#   'not',
#   'doing',
#   'too',
#   'badly',
#   'cheer',
#   'you'],
#  ['tell', 'me', 'anything', 'about', 'you'],
#  ['for',
#   'fear',
#   'of',
#   'fainting',
#   'with',
#   'the',
#   'of',
#   'all',
#   'that',
#   'housework',
#   'you',
#   'just',
#   'did',
#   'quick',
#   'have',
#   'cuppa'],
#  ['thanks',
#   'for',
#   'your',
#   'subscription',
#   'to',
#   'ringtone',
#   'uk',
#   'your',
#   'mobile',
#   'will',
#   'be',
#   'charged',
#   'month',
#   'please',
#   'confirm',
#   'by',
#   'replying',
#   'yes',
#   'or',
#   'no',
#   'if',
#   'you',
#   'reply',
#   'no',
#   'you',
#   'will',
#   'not',
#   'be',
#   'charged'],
#  ['yup',
#   'ok',
#   'go',
#   'home',
#   'look',
#   'at',
#   'the',
#   'timing',
#   'then',
#   'msg',
#   'again',
#   'xuhui',
#   'going',
#   'to',
#   'learn',
#   'on',
#   'nd',
#   'may',
#   'too',
#   'but',
#   'her',
#   'lesson',
#   'is',
#   'at',
#   'am'],
#  ['oops', 'll', 'let', 'you', 'know', 'when', 'my', 'roommate', 'done'],
#  ['see', 'the', 'letter', 'on', 'my', 'car'],
#  ['anything', 'lor', 'decide'],
#  ['hello',
#   'how',
#   'you',
#   'and',
#   'how',
#   'did',
#   'saturday',
#   'go',
#   'wa',
#   'just',
#   'texting',
#   'to',
#   'see',
#   'if',
#   'you',
#   'decided',
#   'to',
#   'do',
#   'anything',
#   'tomo',
#   'not',
#   'that',
#   'trying',
#   'to',
#   'invite',
#   'myself',
#   'or',
#   'anything'],
#  ['pls',
#   'go',
#   'ahead',
#   'with',
#   'watt',
#   'just',
#   'wanted',
#   'to',
#   'be',
#   'sure',
#   'do',
#   'have',
#   'great',
#   'weekend',
#   'abiola'],
#  ['did',
#   'forget',
#   'to',
#   'tell',
#   'you',
#   'want',
#   'you',
#   'need',
#   'you',
#   'crave',
#   'you',
#   'but',
#   'most',
#   'of',
#   'all',
#   'love',
#   'you',
#   'my',
#   'sweet',
#   'arabian',
#   'steed',
#   'mmmmmm',
#   'yummy'],
#  ['rodger',
#   'burn',
#   'msg',
#   'we',
#   'tried',
#   'to',
#   'call',
#   'you',
#   're',
#   'your',
#   'reply',
#   'to',
#   'our',
#   'sm',
#   'for',
#   'free',
#   'nokia',
#   'mobile',
#   'free',
#   'camcorder',
#   'please',
#   'call',
#   'now',
#   'for',
#   'delivery',
#   'tomorrow'],
#  ['who', 'are', 'you', 'seeing'],
#  ['great',
#   'hope',
#   'you',
#   'like',
#   'your',
#   'man',
#   'well',
#   'endowed',
#   'am',
#   'lt',
#   'gt',
#   'inch'],
#  ['no', 'call', 'message', 'missed', 'call'],
#  ['didn', 'you', 'get', 'hep', 'immunisation', 'in', 'nigeria'],
#  ['fair', 'enough', 'anything', 'going', 'on'],
#  ['yeah',
#   'hopefully',
#   'if',
#   'tyler',
#   'can',
#   'do',
#   'it',
#   'could',
#   'maybe',
#   'ask',
#   'around',
#   'bit'],
#  ['don',
#   'know',
#   'how',
#   'stubborn',
#   'am',
#   'didn',
#   'even',
#   'want',
#   'to',
#   'go',
#   'to',
#   'the',
#   'hospital',
#   'kept',
#   'telling',
#   'mark',
#   'not',
#   'weak',
#   'sucker',
#   'hospital',
#   'are',
#   'for',
#   'weak',
#   'sucker'],
#  ['what',
#   'you',
#   'thinked',
#   'about',
#   'me',
#   'first',
#   'time',
#   'you',
#   'saw',
#   'me',
#   'in',
#   'class'],
#  ['gram',
#   'usually',
#   'run',
#   'like',
#   'lt',
#   'gt',
#   'half',
#   'eighth',
#   'is',
#   'smarter',
#   'though',
#   'and',
#   'get',
#   'you',
#   'almost',
#   'whole',
#   'second',
#   'gram',
#   'for',
#   'lt',
#   'gt'],
#  ['fyi',
#   'ha',
#   'ride',
#   'early',
#   'tomorrow',
#   'morning',
#   'but',
#   'he',
#   'crashing',
#   'at',
#   'our',
#   'place',
#   'tonight'],
#  ['wow',
#   'never',
#   'realized',
#   'that',
#   'you',
#   'were',
#   'so',
#   'embarassed',
#   'by',
#   'your',
#   'accomodations',
#   'thought',
#   'you',
#   'liked',
#   'it',
#   'since',
#   'wa',
#   'doing',
#   'the',
#   'best',
#   'could',
#   'and',
#   'you',
#   'always',
#   'seemed',
#   'so',
#   'happy',
#   'about',
#   'the',
#   'cave',
#   'sorry',
#   'didn',
#   'and',
#   'don',
#   'have',
#   'more',
#   'to',
#   'give',
#   'sorry',
#   'offered',
#   'sorry',
#   'your',
#   'room',
#   'wa',
#   'so',
#   'embarassing'],
#  ['sm',
#   'ac',
#   'sptv',
#   'the',
#   'new',
#   'jersey',
#   'devil',
#   'and',
#   'the',
#   'detroit',
#   'red',
#   'wing',
#   'play',
#   'ice',
#   'hockey',
#   'correct',
#   'or',
#   'incorrect',
#   'end',
#   'reply',
#   'end',
#   'sptv'],
#  ['do',
#   'you',
#   'know',
#   'what',
#   'mallika',
#   'sherawat',
#   'did',
#   'yesterday',
#   'find',
#   'out',
#   'now',
#   'lt',
#   'url',
#   'gt'],
#  ['congrats',
#   'year',
#   'special',
#   'cinema',
#   'pas',
#   'for',
#   'is',
#   'yours',
#   'call',
#   'now',
#   'suprman',
#   'matrix',
#   'starwars',
#   'etc',
#   'all',
#   'free',
#   'bx',
#   'ip',
#   'we',
#   'pm',
#   'dont',
#   'miss',
#   'out'],
#  ['sorry', 'll', 'call', 'later', 'in', 'meeting'],
#  ['tell', 'where', 'you', 'reached'],
#  ['yes', 'gauti', 'and', 'sehwag', 'out', 'of', 'odi', 'series'],
#  ['your',
#   'gonna',
#   'have',
#   'to',
#   'pick',
#   'up',
#   'burger',
#   'for',
#   'yourself',
#   'on',
#   'your',
#   'way',
#   'home',
#   'can',
#   'even',
#   'move',
#   'pain',
#   'is',
#   'killing',
#   'me'],
#  ['ha', 'ha', 'ha', 'good', 'joke', 'girl', 'are', 'situation', 'seeker'],
#  ['it', 'part', 'of', 'checking', 'iq'],
#  ['sorry',
#   'my',
#   'roommate',
#   'took',
#   'forever',
#   'it',
#   'ok',
#   'if',
#   'come',
#   'by',
#   'now'],
#  ['ok',
#   'lar',
#   'double',
#   'check',
#   'wif',
#   'da',
#   'hair',
#   'dresser',
#   'already',
#   'he',
#   'said',
#   'wun',
#   'cut',
#   'short',
#   'he',
#   'said',
#   'will',
#   'cut',
#   'until',
#   'look',
#   'nice'],
#  ['valued',
#   'customer',
#   'am',
#   'pleased',
#   'to',
#   'advise',
#   'you',
#   'that',
#   'following',
#   'recent',
#   'review',
#   'of',
#   'your',
#   'mob',
#   'no',
#   'you',
#   'are',
#   'awarded',
#   'with',
#   'bonus',
#   'prize',
#   'call'],
#  ['today',
#   'is',
#   'song',
#   'dedicated',
#   'day',
#   'which',
#   'song',
#   'will',
#   'dedicate',
#   'for',
#   'me',
#   'send',
#   'this',
#   'to',
#   'all',
#   'ur',
#   'valuable',
#   'frnds',
#   'but',
#   'first',
#   'rply',
#   'me'],
#  ['urgent',
#   'ur',
#   'awarded',
#   'complimentary',
#   'trip',
#   'to',
#   'eurodisinc',
#   'trav',
#   'aco',
#   'entry',
#   'or',
#   'to',
#   'claim',
#   'txt',
#   'dis',
#   'to',
#   'morefrmmob',
#   'aj'],
#  ['did',
#   'you',
#   'hear',
#   'about',
#   'the',
#   'new',
#   'divorce',
#   'barbie',
#   'it',
#   'come',
#   'with',
#   'all',
#   'of',
#   'ken',
#   'stuff'],
#  ['plane', 'to', 'give', 'on', 'this', 'month', 'end'],
#  ['wah', 'lucky', 'man', 'then', 'can', 'save', 'money', 'hee'],
#  ['finished', 'class', 'where', 'are', 'you'],
#  ['hi', 'babe', 'im', 'at', 'home', 'now', 'wanna', 'do', 'something', 'xx'],
#  ['where', 'are', 'you', 'how', 'did', 'you', 'performed'],
#  ['can', 'call', 'me', 'now'],
#  ['am', 'waiting', 'machan', 'call', 'me', 'once', 'you', 'free'],
#  ['thats',
#   'cool',
#   'am',
#   'gentleman',
#   'and',
#   'will',
#   'treat',
#   'you',
#   'with',
#   'dignity',
#   'and',
#   'respect'],
#  ['like', 'you', 'people', 'very', 'much', 'but', 'am', 'very', 'shy', 'pa'],
#  ['doe', 'not', 'operate', 'after', 'lt', 'gt', 'or', 'what'],
#  ['it',
#   'not',
#   'the',
#   'same',
#   'here',
#   'still',
#   'looking',
#   'for',
#   'job',
#   'how',
#   'much',
#   'do',
#   'ta',
#   'earn',
#   'there'],
#  ['sorry', 'll', 'call', 'later'],
#  ['did', 'you', 'call', 'me', 'just', 'now', 'ah'],
#  ['ok', 'am', 'on', 'the', 'way', 'to', 'home', 'hi', 'hi'],
#  ['you', 'will', 'be', 'in', 'the', 'place', 'of', 'that', 'man'],
#  ['yup', 'next', 'stop'],
#  ['call', 'you', 'later', 'don', 'have', 'network', 'if', 'urgnt', 'sm', 'me'],
#  ['for',
#   'real',
#   'when',
#   'getting',
#   'on',
#   'yo',
#   'only',
#   'need',
#   'more',
#   'ticket',
#   'and',
#   'one',
#   'more',
#   'jacket',
#   'and',
#   'done',
#   'already',
#   'used',
#   'all',
#   'my',
#   'multis'],
#  ['yes',
#   'started',
#   'to',
#   'send',
#   'request',
#   'to',
#   'make',
#   'it',
#   'but',
#   'pain',
#   'came',
#   'back',
#   'so',
#   'back',
#   'in',
#   'bed',
#   'double',
#   'coin',
#   'at',
#   'the',
#   'factory',
#   'too',
#   'gotta',
#   'cash',
#   'in',
#   'all',
#   'my',
#   'nitros'],
#  ['really', 'not', 'up', 'to', 'it', 'still', 'tonight', 'babe'],
#  ['ela', 'kano', 'il', 'download', 'come', 'wen', 'ur', 'free'],
#  ['yeah',
#   'do',
#   'don',
#   'stand',
#   'to',
#   'close',
#   'tho',
#   'you',
#   'll',
#   'catch',
#   'something'],
#  ['sorry',
#   'to',
#   'be',
#   'pain',
#   'is',
#   'it',
#   'ok',
#   'if',
#   'we',
#   'meet',
#   'another',
#   'night',
#   'spent',
#   'late',
#   'afternoon',
#   'in',
#   'casualty',
#   'and',
#   'that',
#   'mean',
#   'haven',
#   'done',
#   'any',
#   'of',
#   'stuff',
#   'moro',
#   'and',
#   'that',
#   'includes',
#   'all',
#   'my',
#   'time',
#   'sheet',
#   'and',
#   'that',
#   'sorry'],
#  ['smile',
#   'in',
#   'pleasure',
#   'smile',
#   'in',
#   'pain',
#   'smile',
#   'when',
#   'trouble',
#   'pours',
#   'like',
#   'rain',
#   'smile',
#   'when',
#   'sum',
#   'hurt',
#   'smile',
#   'becoz',
#   'someone',
#   'still',
#   'love',
#   'to',
#   'see',
#   'smiling'],
#  ['please',
#   'call',
#   'our',
#   'customer',
#   'service',
#   'representative',
#   'on',
#   'between',
#   'am',
#   'pm',
#   'you',
#   'have',
#   'won',
#   'guaranteed',
#   'cash',
#   'or',
#   'prize'],
#  ['havent',
#   'planning',
#   'to',
#   'buy',
#   'later',
#   'check',
#   'already',
#   'lido',
#   'only',
#   'got',
#   'show',
#   'in',
#   'afternoon',
#   'finish',
#   'work',
#   'already'],
#  ['your',
#   'free',
#   'ringtone',
#   'is',
#   'waiting',
#   'to',
#   'be',
#   'collected',
#   'simply',
#   'text',
#   'the',
#   'password',
#   'mix',
#   'to',
#   'to',
#   'verify',
#   'get',
#   'usher',
#   'and',
#   'britney',
#   'fml'],
#  ['watching', 'telugu', 'movie', 'wat', 'abt'],
#  ['see',
#   'when',
#   'we',
#   'finish',
#   'we',
#   'have',
#   'load',
#   'of',
#   'loan',
#   'to',
#   'pay'],
#  ['hi',
#   'wk',
#   'been',
#   'ok',
#   'on',
#   'hols',
#   'now',
#   'yes',
#   'on',
#   'for',
#   'bit',
#   'of',
#   'run',
#   'forgot',
#   'that',
#   'have',
#   'hairdresser',
#   'appointment',
#   'at',
#   'four',
#   'so',
#   'need',
#   'to',
#   'get',
#   'home',
#   'shower',
#   'beforehand',
#   'doe',
#   'that',
#   'cause',
#   'prob',
#   'for',
#   'ham'],
#  ['please',
#   'don',
#   'text',
#   'me',
#   'anymore',
#   'have',
#   'nothing',
#   'else',
#   'to',
#   'say'],
#  ['okay',
#   'name',
#   'ur',
#   'price',
#   'long',
#   'it',
#   'legal',
#   'wen',
#   'can',
#   'pick',
#   'them',
#   'up',
#   'ave',
#   'am',
#   'xx'],
#  ['still',
#   'looking',
#   'for',
#   'car',
#   'to',
#   'buy',
#   'and',
#   'have',
#   'not',
#   'gone',
#   'the',
#   'driving',
#   'test',
#   'yet'],
#  ['per',
#   'your',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'ha',
#   'been',
#   'set',
#   'your',
#   'callertune',
#   'for',
#   'all',
#   'caller',
#   'press',
#   'to',
#   'copy',
#   'your',
#   'friend',
#   'callertune'],
#  ['wow',
#   'you',
#   're',
#   'right',
#   'didn',
#   'mean',
#   'to',
#   'do',
#   'that',
#   'guess',
#   'once',
#   'gave',
#   'up',
#   'on',
#   'boston',
#   'men',
#   'and',
#   'changed',
#   'my',
#   'search',
#   'location',
#   'to',
#   'nyc',
#   'something',
#   'changed',
#   'cuz',
#   'on',
#   'my',
#   'signin',
#   'page',
#   'it',
#   'still',
#   'say',
#   'boston'],
#  ['umma', 'my', 'life', 'and', 'vava', 'umma', 'love', 'you', 'lot', 'dear'],
#  ['thanks',
#   'lot',
#   'for',
#   'your',
#   'wish',
#   'on',
#   'my',
#   'birthday',
#   'thanks',
#   'you',
#   'for',
#   'making',
#   'my',
#   'birthday',
#   'truly',
#   'memorable'],
#  ['aight', 'll', 'hit', 'you', 'up', 'when', 'get', 'some', 'cash'],
#  ['how',
#   'would',
#   'my',
#   'ip',
#   'address',
#   'test',
#   'that',
#   'considering',
#   'my',
#   'computer',
#   'isn',
#   'minecraft',
#   'server'],
#  ['know',
#   'grumpy',
#   'old',
#   'people',
#   'my',
#   'mom',
#   'wa',
#   'like',
#   'you',
#   'better',
#   'not',
#   'be',
#   'lying',
#   'then',
#   'again',
#   'am',
#   'always',
#   'the',
#   'one',
#   'to',
#   'play',
#   'joke'],
#  ['dont', 'worry', 'guess', 'he', 'busy'],
#  ['what', 'is', 'the', 'plural', 'of', 'the', 'noun', 'research'],
#  ['going', 'for', 'dinner', 'msg', 'you', 'after'],
#  ['ok',
#   'wif',
#   'it',
#   'co',
#   'like',
#   'try',
#   'new',
#   'thing',
#   'but',
#   'scared',
#   'dun',
#   'like',
#   'mah',
#   'co',
#   'said',
#   'not',
#   'too',
#   'loud'],
#  ['gent',
#   'we',
#   'are',
#   'trying',
#   'to',
#   'contact',
#   'you',
#   'last',
#   'weekend',
#   'draw',
#   'show',
#   'that',
#   'you',
#   'won',
#   'prize',
#   'guaranteed',
#   'call',
#   'claim',
#   'code',
#   'valid',
#   'hr',
#   'only',
#   'ppm'],
#  ['wa',
#   'ur',
#   'openin',
#   'sentence',
#   'very',
#   'formal',
#   'anyway',
#   'fine',
#   'too',
#   'juz',
#   'tt',
#   'eatin',
#   'too',
#   'much',
#   'puttin',
#   'on',
#   'weight',
#   'haha',
#   'so',
#   'anythin',
#   'special',
#   'happened'],
#  ['entered',
#   'my',
#   'cabin',
#   'my',
#   'pa',
#   'said',
#   'happy',
#   'day',
#   'bos',
#   'felt',
#   'special',
#   'she',
#   'askd',
#   'me',
#   'lunch',
#   'after',
#   'lunch',
#   'she',
#   'invited',
#   'me',
#   'to',
#   'her',
#   'apartment',
#   'we',
#   'went',
#   'there'],
#  ['you',
#   'are',
#   'winner',
#   'have',
#   'been',
#   'specially',
#   'selected',
#   'receive',
#   'or',
#   'holiday',
#   'flight',
#   'inc',
#   'speak',
#   'to',
#   'live',
#   'operator',
#   'claim',
#   'min'],
#  ['goodo',
#   'yes',
#   'we',
#   'must',
#   'speak',
#   'friday',
#   'egg',
#   'potato',
#   'ratio',
#   'for',
#   'tortilla',
#   'needed'],
#  ['hmm',
#   'my',
#   'uncle',
#   'just',
#   'informed',
#   'me',
#   'that',
#   'he',
#   'paying',
#   'the',
#   'school',
#   'directly',
#   'so',
#   'pls',
#   'buy',
#   'food'],
#  ['private',
#   'your',
#   'account',
#   'statement',
#   'for',
#   'show',
#   'unredeemed',
#   'bonus',
#   'point',
#   'to',
#   'claim',
#   'call',
#   'identifier',
#   'code',
#   'expires'],
#  ['urgent',
#   'your',
#   'mobile',
#   'no',
#   'wa',
#   'awarded',
#   'bonus',
#   'caller',
#   'prize',
#   'on',
#   'this',
#   'is',
#   'our',
#   'final',
#   'try',
#   'to',
#   'contact',
#   'call',
#   'from',
#   'landline',
#   'box',
#   'wr',
#   'ppm'],
#  ['here',
#   'is',
#   'my',
#   'new',
#   'address',
#   'apple',
#   'pair',
#   'all',
#   'that',
#   'malarky'],
#  ['today',
#   'voda',
#   'number',
#   'ending',
#   'are',
#   'selected',
#   'to',
#   'receive',
#   'award',
#   'if',
#   'you',
#   'have',
#   'match',
#   'please',
#   'call',
#   'quoting',
#   'claim',
#   'code',
#   'standard',
#   'rate',
#   'app'],
#  ['am',
#   'going',
#   'to',
#   'sao',
#   'mu',
#   'today',
#   'will',
#   'be',
#   'done',
#   'only',
#   'at'],
#  ['predict', 'wat', 'time', 'll', 'finish', 'buying'],
#  ['good', 'stuff', 'will', 'do'],
#  ['just',
#   'so',
#   'that',
#   'you',
#   'know',
#   'yetunde',
#   'hasn',
#   'sent',
#   'money',
#   'yet',
#   'just',
#   'sent',
#   'her',
#   'text',
#   'not',
#   'to',
#   'bother',
#   'sending',
#   'so',
#   'it',
#   'over',
#   'you',
#   'dont',
#   'have',
#   'to',
#   'involve',
#   'yourself',
#   'in',
#   'anything',
#   'shouldn',
#   'have',
#   'imposed',
#   'anything',
#   'on',
#   'you',
#   'in',
#   'the',
#   'first',
#   'place',
#   'so',
#   'for',
#   'that',
#   'apologise'],
#  ['are', 'you', 'there', 'in', 'room'],
#  ['hey',
#   'girl',
#   'how',
#   'hope',
#   'well',
#   'me',
#   'an',
#   'del',
#   'bak',
#   'again',
#   'long',
#   'time',
#   'no',
#   'give',
#   'me',
#   'call',
#   'sum',
#   'time',
#   'from',
#   'lucyxx'],
#  ['how', 'much', 'doe', 'it', 'cost'],
#  ['home'],
#  ['dear', 'will', 'call', 'tmorrow', 'pls', 'accomodate'],
#  ['first', 'answer', 'my', 'question'],
#  ['sunshine',
#   'quiz',
#   'wkly',
#   'win',
#   'top',
#   'sony',
#   'dvd',
#   'player',
#   'if',
#   'know',
#   'which',
#   'country',
#   'the',
#   'algarve',
#   'is',
#   'in',
#   'txt',
#   'ansr',
#   'to',
#   'sp',
#   'tyrone'],
#  ['want',
#   'get',
#   'laid',
#   'tonight',
#   'want',
#   'real',
#   'dogging',
#   'location',
#   'sent',
#   'direct',
#   'ur',
#   'mob',
#   'join',
#   'the',
#   'uk',
#   'largest',
#   'dogging',
#   'network',
#   'bt',
#   'txting',
#   'gravel',
#   'to',
#   'nt',
#   'ec',
#   'msg'],
#  ['only', 'haf', 'msn', 'it', 'yijue', 'hotmail', 'com'],
#  ['he', 'is', 'there', 'you', 'call', 'and', 'meet', 'him'],
#  ['no', 'no', 'will', 'check', 'all', 'room', 'befor', 'activity'],
#  ['you',
#   'll',
#   'not',
#   'rcv',
#   'any',
#   'more',
#   'msg',
#   'from',
#   'the',
#   'chat',
#   'svc',
#   'for',
#   'free',
#   'hardcore',
#   'service',
#   'text',
#   'go',
#   'to',
#   'if',
#   'get',
#   'nothing',
#   'must',
#   'age',
#   'verify',
#   'with',
#   'yr',
#   'network',
#   'try',
#   'again'],
#  ['got',
#   'lazy',
#   'to',
#   'type',
#   'forgot',
#   'in',
#   'lect',
#   'saw',
#   'pouch',
#   'but',
#   'like',
#   'not',
#   'nice'],
#  ['text', 'me', 'when', 'you', 're', 'on', 'the', 'way'],
#  ['sir', 'waiting', 'for', 'your', 'mail'],
#  ['swt',
#   'thought',
#   'nver',
#   'get',
#   'tired',
#   'of',
#   'doing',
#   'little',
#   'thing',
#   'lovable',
#   'person',
#   'coz',
#   'somtimes',
#   'those',
#   'little',
#   'thing',
#   'occupy',
#   'biggest',
#   'part',
#   'in',
#   'their',
#   'heart',
#   'gud',
#   'ni'],
#  ['know', 'you', 'are', 'can', 'you', 'pls', 'open', 'the', 'back'],
#  ['yes', 'see', 'ya', 'not', 'on', 'the', 'dot'],
#  ['whats', 'the', 'staff', 'name', 'who', 'is', 'taking', 'class', 'for'],
#  ['freemsg',
#   'why',
#   'haven',
#   'you',
#   'replied',
#   'to',
#   'my',
#   'text',
#   'randy',
#   'sexy',
#   'female',
#   'and',
#   'live',
#   'local',
#   'luv',
#   'to',
#   'hear',
#   'from',
#   'netcollex',
#   'ltd',
#   'per',
#   'msg',
#   'reply',
#   'stop',
#   'to',
#   'end'],
#  ['ummma',
#   'will',
#   'call',
#   'after',
#   'check',
#   'in',
#   'our',
#   'life',
#   'will',
#   'begin',
#   'from',
#   'qatar',
#   'so',
#   'pls',
#   'pray',
#   'very',
#   'hard'],
#  ['deleted', 'my', 'contact', 'that', 'why'],
#  ['sindu', 'got', 'job', 'in', 'birla', 'soft'],
#  ['the', 'wine', 'is', 'flowing', 'and', 'have', 'nevering'],
#  ['yup',
#   'thk',
#   'cine',
#   'is',
#   'better',
#   'co',
#   'no',
#   'need',
#   'go',
#   'down',
#   'plaza',
#   'mah'],
#  ['ok', 'ur', 'typical', 'reply'],
#  ['per',
#   'your',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'ha',
#   'been',
#   'set',
#   'your',
#   'callertune',
#   'for',
#   'all',
#   'caller',
#   'press',
#   'to',
#   'copy',
#   'your',
#   'friend',
#   'callertune'],
#  ['you',
#   'are',
#   'everywhere',
#   'dirt',
#   'on',
#   'the',
#   'floor',
#   'the',
#   'window',
#   'even',
#   'on',
#   'my',
#   'shirt',
#   'and',
#   'sometimes',
#   'when',
#   'open',
#   'my',
#   'mouth',
#   'you',
#   'are',
#   'all',
#   'that',
#   'come',
#   'flowing',
#   'out',
#   'dream',
#   'of',
#   'my',
#   'world',
#   'without',
#   'you',
#   'then',
#   'half',
#   'my',
#   'chore',
#   'are',
#   'out',
#   'too',
#   'time',
#   'of',
#   'joy',
#   'for',
#   'me',
#   'lot',
#   'of',
#   'tv',
#   'show',
#   'll',
#   'see',
#   'but',
#   'guess',
#   'like',
#   'all',
#   'thing',
#   'you',
#   'just',
#   'must',
#   'exist',
#   'like',
#   'rain',
#   'hail',
#   'and',
#   'mist',
#   'and',
#   'when',
#   'my',
#   'time',
#   'here',
#   'is',
#   'done',
#   'you',
#   'and',
#   'become',
#   'one'],
#  ['aaooooright', 'are', 'you', 'at', 'work'],
#  ['leaving', 'my', 'house', 'now'],
#  ['hello',
#   'my',
#   'love',
#   'what',
#   'are',
#   'you',
#   'doing',
#   'did',
#   'you',
#   'get',
#   'to',
#   'that',
#   'interview',
#   'today',
#   'are',
#   'you',
#   'you',
#   'happy',
#   'are',
#   'you',
#   'being',
#   'good',
#   'boy',
#   'do',
#   'you',
#   'think',
#   'of',
#   'me',
#   'are',
#   'you',
#   'missing',
#   'me'],
#  ['customer',
#   'service',
#   'annoncement',
#   'you',
#   'have',
#   'new',
#   'year',
#   'delivery',
#   'waiting',
#   'for',
#   'you',
#   'please',
#   'call',
#   'now',
#   'to',
#   'arrange',
#   'delivery'],
#  ['you',
#   'are',
#   'winner',
#   'have',
#   'been',
#   'specially',
#   'selected',
#   'receive',
#   'cash',
#   'or',
#   'holiday',
#   'flight',
#   'inc',
#   'speak',
#   'to',
#   'live',
#   'operator',
#   'claim'],
#  ['keep',
#   'yourself',
#   'safe',
#   'for',
#   'me',
#   'because',
#   'need',
#   'you',
#   'and',
#   'miss',
#   'you',
#   'already',
#   'and',
#   'envy',
#   'everyone',
#   'that',
#   'see',
#   'you',
#   'in',
#   'real',
#   'life'],
#  ['new',
#   'car',
#   'and',
#   'house',
#   'for',
#   'my',
#   'parent',
#   'have',
#   'only',
#   'new',
#   'job',
#   'in',
#   'hand'],
#  ['so',
#   'in',
#   'love',
#   'with',
#   'you',
#   'excited',
#   'each',
#   'day',
#   'spend',
#   'with',
#   'you',
#   'you',
#   'make',
#   'me',
#   'so',
#   'happy'],
#  ['pls',
#   'stop',
#   'bootydelious',
#   'is',
#   'inviting',
#   'you',
#   'to',
#   'be',
#   'her',
#   'friend',
#   'reply',
#   'yes',
#   'or',
#   'no',
#   'see',
#   'her',
#   'www',
#   'sm',
#   'ac',
#   'bootydelious',
#   'stop',
#   'send',
#   'stop',
#   'frnd',
#   'to'],
#  ['bangbabes',
#   'ur',
#   'order',
#   'is',
#   'on',
#   'the',
#   'way',
#   'should',
#   'receive',
#   'service',
#   'msg',
#   'download',
#   'ur',
#   'content',
#   'if',
#   'do',
#   'not',
#   'goto',
#   'wap',
#   'bangb',
#   'tv',
#   'on',
#   'ur',
#   'mobile',
#   'internet',
#   'service',
#   'menu'],
#  ['place', 'all', 'ur', 'point', 'on', 'culture', 'module', 'already'],
#  ['urgent',
#   'we',
#   'are',
#   'trying',
#   'to',
#   'contact',
#   'you',
#   'last',
#   'weekend',
#   'draw',
#   'show',
#   'that',
#   'you',
#   'have',
#   'won',
#   'prize',
#   'guaranteed',
#   'call',
#   'claim',
#   'code',
#   'valid',
#   'hr',
#   'only'],
#  ['hi',
#   'frnd',
#   'which',
#   'is',
#   'best',
#   'way',
#   'to',
#   'avoid',
#   'missunderstding',
#   'wit',
#   'our',
#   'beloved',
#   'one'],
#  ['great',
#   'escape',
#   'fancy',
#   'the',
#   'bridge',
#   'but',
#   'need',
#   'her',
#   'lager',
#   'see',
#   'you',
#   'tomo'],
#  ['yes',
#   'it',
#   'completely',
#   'in',
#   'out',
#   'of',
#   'form',
#   'clark',
#   'also',
#   'utter',
#   'waste'],
#  ['sir', 'need', 'axis', 'bank', 'account', 'no', 'and', 'bank', 'address'],
#  ['hmmm',
#   'thk',
#   'sure',
#   'got',
#   'time',
#   'to',
#   'hop',
#   'ard',
#   'ya',
#   'can',
#   'go',
#   'free',
#   'abt',
#   'muz',
#   'call',
#   'to',
#   'discus',
#   'liao'],
#  ['what', 'time', 'you', 'coming', 'down', 'later'],
#  ['bloody',
#   'hell',
#   'cant',
#   'believe',
#   'you',
#   'forgot',
#   'my',
#   'surname',
#   'mr',
#   'ill',
#   'give',
#   'clue',
#   'it',
#   'spanish',
#   'and',
#   'begin',
#   'with'],
#  ['well',
#   'gonna',
#   'finish',
#   'my',
#   'bath',
#   'now',
#   'have',
#   'good',
#   'fine',
#   'night'],
#  ['let',
#   'me',
#   'know',
#   'when',
#   'you',
#   've',
#   'got',
#   'the',
#   'money',
#   'so',
#   'carlos',
#   'can',
#   'make',
#   'the',
#   'call'],
#  ['still', 'going', 'to', 'the', 'mall'],
#  ['turn',
#   'out',
#   'my',
#   'friend',
#   'are',
#   'staying',
#   'for',
#   'the',
#   'whole',
#   'show',
#   'and',
#   'won',
#   'be',
#   'back',
#   'til',
#   'lt',
#   'gt',
#   'so',
#   'feel',
#   'free',
#   'to',
#   'go',
#   'ahead',
#   'and',
#   'smoke',
#   'that',
#   'lt',
#   'gt',
#   'worth'],
#  ['text',
#   'her',
#   'if',
#   'she',
#   'doesnt',
#   'reply',
#   'let',
#   'me',
#   'know',
#   'so',
#   'can',
#   'have',
#   'her',
#   'log',
#   'in'],
#  ['hi',
#   'you',
#   'just',
#   'spoke',
#   'to',
#   'maneesha',
#   'we',
#   'like',
#   'to',
#   'know',
#   'if',
#   'you',
#   'were',
#   'satisfied',
#   'with',
#   'the',
#   'experience',
#   'reply',
#   'toll',
#   'free',
#   'with',
#   'yes',
#   'or',
#   'no'],
#  ['you',
#   'lifted',
#   'my',
#   'hope',
#   'with',
#   'the',
#   'offer',
#   'of',
#   'money',
#   'am',
#   'in',
#   'need',
#   'especially',
#   'when',
#   'the',
#   'end',
#   'of',
#   'the',
#   'month',
#   'approach',
#   'and',
#   'it',
#   'hurt',
#   'my',
#   'studying',
#   'anyways',
#   'have',
#   'gr',
#   'weekend'],
#  ['lol', 'no', 'can', 'trust', 'me'],
#  ['ok',
#   'am',
#   'gentleman',
#   'and',
#   'will',
#   'treat',
#   'you',
#   'with',
#   'dignity',
#   'and',
#   'respect'],
#  ['he', 'will', 'you', 'guy', 'close'],
#  ['going', 'on', 'nothing', 'great', 'bye'],
#  ['hello',
#   'handsome',
#   'are',
#   'you',
#   'finding',
#   'that',
#   'job',
#   'not',
#   'being',
#   'lazy',
#   'working',
#   'towards',
#   'getting',
#   'back',
#   'that',
#   'net',
#   'for',
#   'mummy',
#   'where',
#   'my',
#   'boytoy',
#   'now',
#   'doe',
#   'he',
#   'miss',
#   'me'],
#  ['haha', 'awesome', 'be', 'there', 'in', 'minute'],
#  ['please',
#   'call',
#   'our',
#   'customer',
#   'service',
#   'representative',
#   'on',
#   'freephone',
#   'between',
#   'am',
#   'pm',
#   'you',
#   'have',
#   'won',
#   'guaranteed',
#   'cash',
#   'or',
#   'prize'],
#  ['have',
#   'you',
#   'got',
#   'xmas',
#   'radio',
#   'time',
#   'if',
#   'not',
#   'will',
#   'get',
#   'it',
#   'now'],
#  ['jus',
#   'reached',
#   'home',
#   'go',
#   'bathe',
#   'first',
#   'but',
#   'my',
#   'si',
#   'using',
#   'net',
#   'tell',
#   'when',
#   'she',
#   'finish'],
#  ['are',
#   'you',
#   'unique',
#   'enough',
#   'find',
#   'out',
#   'from',
#   'th',
#   'august',
#   'www',
#   'areyouunique',
#   'co',
#   'uk'],
#  ['sorry',
#   've',
#   'joined',
#   'the',
#   'league',
#   'of',
#   'people',
#   'that',
#   'dont',
#   'keep',
#   'in',
#   'touch',
#   'you',
#   'mean',
#   'great',
#   'deal',
#   'to',
#   'me',
#   'you',
#   'have',
#   'been',
#   'friend',
#   'at',
#   'all',
#   'time',
#   'even',
#   'at',
#   'great',
#   'personal',
#   'cost',
#   'do',
#   'have',
#   'great',
#   'week'],
#  ['hi', 'finally', 'completed', 'the', 'course'],
#  ['it',
#   'will',
#   'stop',
#   'on',
#   'itself',
#   'however',
#   'suggest',
#   'she',
#   'stay',
#   'with',
#   'someone',
#   'that',
#   'will',
#   'be',
#   'able',
#   'to',
#   'give',
#   'or',
#   'for',
#   'every',
#   'stool'],
#  ['how',
#   'are',
#   'you',
#   'doing',
#   'hope',
#   'you',
#   've',
#   'settled',
#   'in',
#   'for',
#   'the',
#   'new',
#   'school',
#   'year',
#   'just',
#   'wishin',
#   'you',
#   'gr',
#   'day'],
#  ['gud', 'mrng', 'dear', 'hav', 'nice', 'day'],
#  ['did', 'got', 'that', 'person', 'story'],
#  ['is',
#   'your',
#   'hamster',
#   'dead',
#   'hey',
#   'so',
#   'tmr',
#   'meet',
#   'you',
#   'at',
#   'pm',
#   'orchard',
#   'mrt'],
#  ['hi',
#   'it',
#   'kate',
#   'how',
#   'is',
#   'your',
#   'evening',
#   'hope',
#   'can',
#   'see',
#   'you',
#   'tomorrow',
#   'for',
#   'bit',
#   'but',
#   'have',
#   'to',
#   'bloody',
#   'babyjontet',
#   'txt',
#   'back',
#   'if',
#   'can',
#   'xxx'],
#  ['found', 'it', 'enc', 'lt', 'gt', 'where', 'you', 'at'],
#  ['sent', 'you', 'lt', 'gt', 'buck'],
#  ['hello',
#   'darlin',
#   'ive',
#   'finished',
#   'college',
#   'now',
#   'so',
#   'txt',
#   'me',
#   'when',
#   'finish',
#   'if',
#   'can',
#   'love',
#   'kate',
#   'xxx'],
#  ['your',
#   'account',
#   'ha',
#   'been',
#   'refilled',
#   'successfully',
#   'by',
#   'inr',
#   'lt',
#   'decimal',
#   'gt',
#   'your',
#   'keralacircle',
#   'prepaid',
#   'account',
#   'balance',
#   'is',
#   'lt',
#   'decimal',
#   'gt',
#   'your',
#   'transaction',
#   'id',
#   'is',
#   'kr',
#   'lt',
#   'gt'],
#  ['goodmorning', 'sleeping', 'ga'],
#  ['call', 'me', 'alter', 'at', 'ok'],
#  ['say',
#   'until',
#   'like',
#   'dat',
#   'dun',
#   'buy',
#   'ericsson',
#   'oso',
#   'cannot',
#   'oredi',
#   'lar'],
#  ['entered',
#   'my',
#   'cabin',
#   'my',
#   'pa',
#   'said',
#   'happy',
#   'day',
#   'bos',
#   'felt',
#   'special',
#   'she',
#   'askd',
#   'me',
#   'lunch',
#   'after',
#   'lunch',
#   'she',
#   'invited',
#   'me',
#   'to',
#   'her',
#   'apartment',
#   'we',
#   'went',
#   'there'],
#  ['aight', 'yo', 'dat', 'straight', 'dogg'],
#  ['you',
#   'please',
#   'give',
#   'connection',
#   'today',
#   'itself',
#   'before',
#   'lt',
#   'decimal',
#   'gt',
#   'or',
#   'refund',
#   'the',
#   'bill'],
#  ['both', 'shoot', 'big', 'load', 'so', 'get', 'ready'],
#  ['what',
#   'up',
#   'bruv',
#   'hope',
#   'you',
#   'had',
#   'great',
#   'break',
#   'do',
#   'have',
#   'rewarding',
#   'semester'],
#  ['home', 'so', 'we', 'can', 'always', 'chat'],
#  ['good', 'study', 'well'],
#  ['yup', 'how', 'noe', 'leh'],
#  ['sound', 'great', 'are', 'you', 'home', 'now'],
#  ['finally',
#   'the',
#   'match',
#   'heading',
#   'towards',
#   'draw',
#   'your',
#   'prediction'],
#  ['tired', 'haven', 'slept', 'well', 'the', 'past', 'few', 'night'],
#  ['easy', 'ah', 'sen', 'got', 'selected', 'mean', 'it', 'good'],
#  ['have', 'to', 'take', 'exam', 'with', 'march'],
#  ['yeah',
#   'you',
#   'should',
#   'think',
#   'you',
#   'can',
#   'use',
#   'your',
#   'gt',
#   'atm',
#   'now',
#   'to',
#   'register',
#   'not',
#   'sure',
#   'but',
#   'if',
#   'there',
#   'anyway',
#   'can',
#   'help',
#   'let',
#   'me',
#   'know',
#   'but',
#   'when',
#   'you',
#   'do',
#   'be',
#   'sure',
#   'you',
#   'are',
#   'ready'],
#  ['ok', 'no', 'prob', 'take', 'ur', 'time'],
#  ['there',
#   'is',
#   'called',
#   'ubandu',
#   'which',
#   'will',
#   'run',
#   'without',
#   'installing',
#   'in',
#   'hard',
#   'disk',
#   'you',
#   'can',
#   'use',
#   'that',
#   'to',
#   'copy',
#   'the',
#   'important',
#   'file',
#   'in',
#   'system',
#   'and',
#   'give',
#   'it',
#   'to',
#   'repair',
#   'shop'],
#  ['sorry', 'll', 'call', 'later'],
#  ['say',
#   'leh',
#   'of',
#   'course',
#   'nothing',
#   'happen',
#   'lar',
#   'not',
#   'say',
#   'romantic',
#   'jus',
#   'bit',
#   'only',
#   'lor',
#   'thk',
#   'nite',
#   'scenery',
#   'not',
#   'so',
#   'nice',
#   'leh'],
#  ['new',
#   'mobile',
#   'from',
#   'must',
#   'go',
#   'txt',
#   'nokia',
#   'to',
#   'no',
#   'collect',
#   'yours',
#   'today',
#   'from',
#   'only',
#   'www',
#   'tc',
#   'biz',
#   'optout',
#   'gbp',
#   'mtmsg'],
#  ['would',
#   'really',
#   'appreciate',
#   'if',
#   'you',
#   'call',
#   'me',
#   'just',
#   'need',
#   'someone',
#   'to',
#   'talk',
#   'to'],
#  ['will',
#   'meet',
#   'ur',
#   'dream',
#   'partner',
#   'soon',
#   'is',
#   'ur',
#   'career',
#   'off',
#   'flyng',
#   'start',
#   'find',
#   'out',
#   'free',
#   'txt',
#   'horo',
#   'followed',
#   'by',
#   'ur',
#   'star',
#   'sign',
#   'horo',
#   'aries'],
#  ['hey', 'company', 'elama', 'po', 'mudyadhu'],
#  ['life',
#   'is',
#   'more',
#   'strict',
#   'than',
#   'teacher',
#   'bcoz',
#   'teacher',
#   'teach',
#   'lesson',
#   'amp',
#   'then',
#   'conduct',
#   'exam',
#   'but',
#   'life',
#   'first',
#   'conduct',
#   'exam',
#   'amp',
#   'then',
#   'teach',
#   'lesson',
#   'happy',
#   'morning'],
#  ['dear', 'good', 'morning', 'now', 'only', 'am', 'up'],
#  ['get',
#   'down',
#   'in',
#   'gandhipuram',
#   'and',
#   'walk',
#   'to',
#   'cross',
#   'cut',
#   'road',
#   'right',
#   'side',
#   'lt',
#   'gt',
#   'street',
#   'road',
#   'and',
#   'turn',
#   'at',
#   'first',
#   'right'],
#  ['dear', 'we', 'are', 'going', 'to', 'our', 'rubber', 'place'],
#  ['sorry', 'battery', 'died', 'yeah', 'here'],
#  ['yes', 'here', 'tv', 'is', 'always', 'available', 'in', 'work', 'place'],
#  ['text',
#   'meet',
#   'someone',
#   'sexy',
#   'today',
#   'can',
#   'find',
#   'date',
#   'or',
#   'even',
#   'flirt',
#   'it',
#   'up',
#   'to',
#   'join',
#   'just',
#   'reply',
#   'with',
#   'name',
#   'age',
#   'eg',
#   'sam',
#   'msg',
#   'recd',
#   'thirtyeight',
#   'penny'],
#  ['have', 'printed', 'it', 'oh', 'so', 'lt', 'gt', 'come', 'upstairs'],
#  ['or',
#   'ill',
#   'be',
#   'little',
#   'closer',
#   'like',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'on',
#   'the',
#   'same',
#   'street'],
#  ['where', 'are', 'you', 'when', 'wil', 'you', 'reach', 'here'],
#  ['new',
#   'theory',
#   'argument',
#   'win',
#   'situation',
#   'but',
#   'loses',
#   'the',
#   'person',
#   'so',
#   'dont',
#   'argue',
#   'with',
#   'ur',
#   'friend',
#   'just',
#   'kick',
#   'them',
#   'amp',
#   'say',
#   'always',
#   'correct'],
#  ['have',
#   'secret',
#   'admirer',
#   'who',
#   'is',
#   'looking',
#   'make',
#   'contact',
#   'with',
#   'find',
#   'out',
#   'who',
#   'they',
#   'reveal',
#   'who',
#   'think',
#   'ur',
#   'so',
#   'special',
#   'call',
#   'on'],
#  ['tomarrow', 'final', 'hearing', 'on', 'my', 'laptop', 'case', 'so', 'cant'],
#  ['tel', 'me', 'avent', 'done', 'sportsx'],
#  ['okay',
#   'no',
#   'no',
#   'just',
#   'shining',
#   'on',
#   'that',
#   'wa',
#   'meant',
#   'to',
#   'be',
#   'signing',
#   'but',
#   'that',
#   'sound',
#   'better'],
#  ['although',
#   'told',
#   'dat',
#   'into',
#   'baig',
#   'face',
#   'watch',
#   'now',
#   'but',
#   'really',
#   'like',
#   'watch',
#   'gave',
#   'co',
#   'it',
#   'fr',
#   'thanx',
#   'everything',
#   'dat',
#   've',
#   'done',
#   'today',
#   'touched'],
#  ['don', 'remember', 'that', 'old', 'commercial'],
#  ['too',
#   'late',
#   'said',
#   'have',
#   'the',
#   'website',
#   'didn',
#   'have',
#   'or',
#   'dont',
#   'have',
#   'the',
#   'slipper'],
#  ['asked', 'you', 'to', 'call', 'him', 'now', 'ok'],
#  ['kallis', 'wont', 'bat', 'in', 'nd', 'inning'],
#  ['it',
#   'didnt',
#   'work',
#   'again',
#   'oh',
#   'ok',
#   'goodnight',
#   'then',
#   'll',
#   'fix',
#   'and',
#   'have',
#   'it',
#   'ready',
#   'by',
#   'the',
#   'time',
#   'you',
#   'wake',
#   'up',
#   'you',
#   'are',
#   'very',
#   'dearly',
#   'missed',
#   'have',
#   'good',
#   'night',
#   'sleep'],
#  ['congratulation',
#   'ur',
#   'awarded',
#   'of',
#   'cd',
#   'voucher',
#   'or',
#   'gift',
#   'guaranteed',
#   'free',
#   'entry',
#   'wkly',
#   'draw',
#   'txt',
#   'music',
#   'to',
#   'tncs',
#   'www',
#   'ldew',
#   'com',
#   'win',
#   'ppmx',
#   'age'],
#  ['ranjith', 'cal', 'drpd', 'deeraj', 'and', 'deepak', 'min', 'hold'],
#  ['wen',
#   'ur',
#   'lovable',
#   'bcums',
#   'angry',
#   'wid',
#   'dnt',
#   'take',
#   'it',
#   'seriously',
#   'coz',
#   'being',
#   'angry',
#   'is',
#   'most',
#   'childish',
#   'true',
#   'way',
#   'of',
#   'showing',
#   'deep',
#   'affection',
#   'care',
#   'luv',
#   'kettoda',
#   'manda',
#   'have',
#   'nice',
#   'day',
#   'da'],
#  ['what', 'you', 'doing', 'how', 'are', 'you'],
#  ['ups',
#   'which',
#   'is',
#   'day',
#   'also',
#   'and',
#   'the',
#   'shipping',
#   'company',
#   'that',
#   'take',
#   'wks',
#   'the',
#   'other',
#   'way',
#   'is',
#   'usps',
#   'which',
#   'take',
#   'week',
#   'but',
#   'when',
#   'it',
#   'get',
#   'to',
#   'lag',
#   'you',
#   'may',
#   'have',
#   'to',
#   'bribe',
#   'nipost',
#   'to',
#   'get',
#   'your',
#   'stuff'],
#  ['back', 'lemme', 'know', 'when', 'you', 're', 'ready'],
#  ['don',
#   'necessarily',
#   'expect',
#   'it',
#   'to',
#   'be',
#   'done',
#   'before',
#   'you',
#   'get',
#   'back',
#   'though',
#   'because',
#   'just',
#   'now',
#   'headin',
#   'out'],
#  ['mmm', 'so', 'yummy', 'babe', 'nice', 'jolt', 'to', 'the', 'suzy'],
#  ['where', 'are', 'you', 'lover', 'need', 'you'],
#  ['we',
#   'tried',
#   'to',
#   'contact',
#   'you',
#   're',
#   'your',
#   'reply',
#   'to',
#   'our',
#   'offer',
#   'of',
#   'video',
#   'handset',
#   'anytime',
#   'network',
#   'min',
#   'unlimited',
#   'text',
#   'camcorder',
#   'reply',
#   'or',
#   'call',
#   'now'],
#  ['parked',
#   'next',
#   'to',
#   'mini',
#   'when',
#   'are',
#   'you',
#   'coming',
#   'in',
#   'today',
#   'do',
#   'you',
#   'think'],
#  ['yup'],
#  ['anyway',
#   'going',
#   'shopping',
#   'on',
#   'my',
#   'own',
#   'now',
#   'co',
#   'my',
#   'si',
#   'not',
#   'done',
#   'yet',
#   'dun',
#   'disturb',
#   'liao'],
#  ['my', 'no', 'in', 'luton', 'ring', 'me', 'if', 'ur', 'around'],
#  ['hey',
#   'am',
#   'really',
#   'horny',
#   'want',
#   'to',
#   'chat',
#   'or',
#   'see',
#   'me',
#   'naked',
#   'text',
#   'hot',
#   'to',
#   'text',
#   'charged',
#   'at',
#   'pm',
#   'to',
#   'unsubscribe',
#   'text',
#   'stop'],
#  ['why', 'you', 'dint', 'come', 'with'],
#  ['same', 'wana', 'plan', 'trip', 'sometme', 'then'],
#  ['not', 'sure', 'yet', 'still', 'trying', 'to', 'get', 'hold', 'of', 'him'],
#  ['ur',
#   'ringtone',
#   'service',
#   'ha',
#   'changed',
#   'free',
#   'credit',
#   'go',
#   'to',
#   'club',
#   'mobile',
#   'com',
#   'to',
#   'choose',
#   'content',
#   'now',
#   'stop',
#   'txt',
#   'club',
#   'stop',
#   'to',
#   'wk',
#   'club',
#   'po',
#   'box',
#   'mk',
#   'wt'],
#  ['the', 'evo', 'just', 'had', 'to', 'download', 'flash', 'jealous'],
#  ['ringtone',
#   'club',
#   'get',
#   'the',
#   'uk',
#   'single',
#   'chart',
#   'on',
#   'your',
#   'mobile',
#   'each',
#   'week',
#   'and',
#   'choose',
#   'any',
#   'top',
#   'quality',
#   'ringtone',
#   'this',
#   'message',
#   'is',
#   'free',
#   'of',
#   'charge'],
#  ['come',
#   'to',
#   'mu',
#   'we',
#   're',
#   'sorting',
#   'out',
#   'our',
#   'narcotic',
#   'situation'],
#  ['night',
#   'ha',
#   'ended',
#   'for',
#   'another',
#   'day',
#   'morning',
#   'ha',
#   'come',
#   'in',
#   'special',
#   'way',
#   'may',
#   'you',
#   'smile',
#   'like',
#   'the',
#   'sunny',
#   'ray',
#   'and',
#   'leaf',
#   'your',
#   'worry',
#   'at',
#   'the',
#   'blue',
#   'blue',
#   'bay'],
#  ['hmv',
#   'bonus',
#   'special',
#   'pound',
#   'of',
#   'genuine',
#   'hmv',
#   'voucher',
#   'to',
#   'be',
#   'won',
#   'just',
#   'answer',
#   'easy',
#   'question',
#   'play',
#   'now',
#   'send',
#   'hmv',
#   'to',
#   'more',
#   'info',
#   'www',
#   'percent',
#   'real',
#   'com'],
#  ['usf', 'guess', 'might', 'well', 'take', 'car'],
#  ['no', 'objection', 'my', 'bf', 'not', 'coming'],
#  ['thanx'],
#  ['tell', 'rob', 'to', 'mack', 'his', 'gf', 'in', 'the', 'theater'],
#  ['awesome', 'll', 'see', 'you', 'in', 'bit'],
#  ['just',
#   'sent',
#   'it',
#   'so',
#   'what',
#   'type',
#   'of',
#   'food',
#   'do',
#   'you',
#   'like'],
#  ['all',
#   'done',
#   'all',
#   'handed',
#   'in',
#   'celebration',
#   'in',
#   'full',
#   'swing',
#   'yet'],
#  ['you', 'got', 'called', 'tool'],
#  ['wen', 'miss', 'someone'],
#  ['ok', 'asked', 'for', 'money', 'how', 'far'],
#  ['okie'],
#  ['yeah',
#   'think',
#   'my',
#   'usual',
#   'guy',
#   'still',
#   'passed',
#   'out',
#   'from',
#   'last',
#   'night',
#   'if',
#   'you',
#   'get',
#   'ahold',
#   'of',
#   'anybody',
#   'let',
#   'me',
#   'know',
#   'and',
#   'll',
#   'throw',
#   'down'],
#  ['might',
#   'come',
#   'by',
#   'tonight',
#   'then',
#   'if',
#   'my',
#   'class',
#   'let',
#   'out',
#   'early'],
#  ['ok'],
#  ['hi',
#   'baby',
#   'im',
#   'cruisin',
#   'with',
#   'my',
#   'girl',
#   'friend',
#   'what',
#   'up',
#   'give',
#   'me',
#   'call',
#   'in',
#   'and',
#   'hour',
#   'at',
#   'home',
#   'if',
#   'thats',
#   'alright',
#   'or',
#   'fone',
#   'me',
#   'on',
#   'this',
#   'fone',
#   'now',
#   'love',
#   'jenny',
#   'xxx'],
#  ['my',
#   'life',
#   'mean',
#   'lot',
#   'to',
#   'me',
#   'not',
#   'because',
#   'love',
#   'my',
#   'life',
#   'but',
#   'because',
#   'love',
#   'the',
#   'people',
#   'in',
#   'my',
#   'life',
#   'the',
#   'world',
#   'call',
#   'them',
#   'friend',
#   'call',
#   'them',
#   'my',
#   'world',
#   'ge'],
#  ['dear',
#   'shall',
#   'mail',
#   'tonite',
#   'busy',
#   'in',
#   'the',
#   'street',
#   'shall',
#   'update',
#   'you',
#   'tonite',
#   'thing',
#   'are',
#   'looking',
#   'ok',
#   'varunnathu',
#   'edukkukayee',
#   'raksha',
#   'ollu',
#   'but',
#   'good',
#   'one',
#   'in',
#   'real',
#   'sense'],
#  ['hey', 'you', 'told', 'your', 'name', 'to', 'gautham', 'ah'],
#  ['haf', 'found', 'him', 'feel', 'so', 'stupid', 'da', 'cam', 'wa', 'working'],
#  ['oops', 'got', 'that', 'bit'],
#  ['are', 'you', 'this', 'much', 'buzy'],
#  ['accidentally', 'deleted', 'the', 'message', 'resend', 'please'],
#  ['mobile',
#   'customer',
#   'you',
#   'may',
#   'now',
#   'claim',
#   'your',
#   'free',
#   'camera',
#   'phone',
#   'upgrade',
#   'pay',
#   'go',
#   'sim',
#   'card',
#   'for',
#   'your',
#   'loyalty',
#   'call',
#   'on',
#   'offer',
#   'end',
#   'thfeb',
#   'apply'],
#  ['unless',
#   'it',
#   'situation',
#   'where',
#   'you',
#   'go',
#   'gurl',
#   'would',
#   'be',
#   'more',
#   'appropriate'],
#  ['hurt',
#   'me',
#   'tease',
#   'me',
#   'make',
#   'me',
#   'cry',
#   'but',
#   'in',
#   'the',
#   'end',
#   'of',
#   'my',
#   'life',
#   'when',
#   'die',
#   'plz',
#   'keep',
#   'one',
#   'rose',
#   'on',
#   'my',
#   'grave',
#   'and',
#   'say',
#   'stupid',
#   'miss',
#   'have',
#   'nice',
#   'day',
#   'bslvyl'],
#  ['cant', 'pick', 'the', 'phone', 'right', 'now', 'pls', 'send', 'message'],
#  ['need',
#   'coffee',
#   'run',
#   'tomo',
#   'can',
#   'believe',
#   'it',
#   'that',
#   'time',
#   'of',
#   'week',
#   'already'],
#  ['awesome',
#   'remember',
#   'the',
#   'last',
#   'time',
#   'we',
#   'got',
#   'somebody',
#   'high',
#   'for',
#   'the',
#   'first',
#   'time',
#   'with',
#   'diesel'],
#  ['shit',
#   'that',
#   'is',
#   'really',
#   'shocking',
#   'and',
#   'scary',
#   'cant',
#   'imagine',
#   'for',
#   'second',
#   'def',
#   'up',
#   'for',
#   'night',
#   'out',
#   'do',
#   'think',
#   'there',
#   'is',
#   'somewhere',
#   'could',
#   'crash',
#   'for',
#   'night',
#   'save',
#   'on',
#   'taxi'],
#  ['oh',
#   'and',
#   'by',
#   'the',
#   'way',
#   'you',
#   'do',
#   'have',
#   'more',
#   'food',
#   'in',
#   'your',
#   'fridge',
#   'want',
#   'to',
#   'go',
#   'out',
#   'for',
#   'meal',
#   'tonight'],
#  ['he', 'is', 'womdarfull', 'actor'],
#  ['sm',
#   'ac',
#   'blind',
#   'date',
#   'rodds',
#   'is',
#   'from',
#   'aberdeen',
#   'united',
#   'kingdom',
#   'check',
#   'him',
#   'out',
#   'http',
#   'img',
#   'sm',
#   'ac',
#   'icmb',
#   'cktz',
#   'no',
#   'blind',
#   'date',
#   'send',
#   'hide'],
#  ['yup', 'from', 'what', 'remb', 'think', 'should', 'be', 'can', 'book'],
#  ['jos', 'ask', 'if', 'wana', 'meet', 'up'],
#  ['lol',
#   'yes',
#   'our',
#   'friendship',
#   'is',
#   'hanging',
#   'on',
#   'thread',
#   'cause',
#   'won',
#   'buy',
#   'stuff'],
#  ['themob',
#   'check',
#   'out',
#   'our',
#   'newest',
#   'selection',
#   'of',
#   'content',
#   'game',
#   'tone',
#   'gossip',
#   'babe',
#   'and',
#   'sport',
#   'keep',
#   'your',
#   'mobile',
#   'fit',
#   'and',
#   'funky',
#   'text',
#   'wap',
#   'to'],
#  ['where',
#   'are',
#   'the',
#   'garage',
#   'key',
#   'they',
#   'aren',
#   'on',
#   'the',
#   'bookshelf'],
#  ['today',
#   'is',
#   'accept',
#   'day',
#   'accept',
#   'me',
#   'brother',
#   'sister',
#   'lover',
#   'dear',
#   'best',
#   'clos',
#   'lvblefrnd',
#   'jstfrnd',
#   'cutefrnd',
#   'lifpartnr',
#   'belovd',
#   'swtheart',
#   'bstfrnd',
#   'no',
#   'rply',
#   'mean',
#   'enemy'],
#  ['think',
#   'ur',
#   'smart',
#   'win',
#   'this',
#   'week',
#   'in',
#   'our',
#   'weekly',
#   'quiz',
#   'text',
#   'play',
#   'to',
#   'now',
#   'winnersclub',
#   'po',
#   'box',
#   'uz',
#   'gbp',
#   'week'],
#  ['he',
#   'say',
#   'he',
#   'll',
#   'give',
#   'me',
#   'call',
#   'when',
#   'his',
#   'friend',
#   'got',
#   'the',
#   'money',
#   'but',
#   'that',
#   'he',
#   'definitely',
#   'buying',
#   'before',
#   'the',
#   'end',
#   'of',
#   'the',
#   'week'],
#  ['hi',
#   'the',
#   'way',
#   'wa',
#   'with',
#   'day',
#   'is',
#   'the',
#   'normal',
#   'way',
#   'this',
#   'is',
#   'the',
#   'real',
#   'me',
#   'ur',
#   'unique',
#   'hope',
#   'know',
#   'the',
#   'rest',
#   'of',
#   'mylife',
#   'hope',
#   'find',
#   'wot',
#   'wa',
#   'lost'],
#  ['you', 'made', 'my', 'day', 'do', 'have', 'great', 'day', 'too'],
#  ['advance', 'happy', 'pongal'],
#  ['hmmm',
#   'guess',
#   'we',
#   'can',
#   'go',
#   'kb',
#   'power',
#   'yoga',
#   'haha',
#   'dunno',
#   'we',
#   'can',
#   'tahan',
#   'power',
#   'yoga',
#   'anot',
#   'thk',
#   'got',
#   'lo',
#   'oso',
#   'forgot',
#   'liao'],
#  ['not', 'really', 'dude', 'have', 'no', 'friend', 'afraid'],
#  ['december',
#   'only',
#   'had',
#   'your',
#   'mobile',
#   'mths',
#   'you',
#   'are',
#   'entitled',
#   'to',
#   'update',
#   'to',
#   'the',
#   'latest',
#   'colour',
#   'camera',
#   'mobile',
#   'for',
#   'free',
#   'call',
#   'the',
#   'mobile',
#   'update',
#   'co',
#   'free',
#   'on'],
#  ['coffee', 'cake', 'guess'],
#  ['merry', 'christmas', 'to', 'you', 'too', 'babe', 'love', 'ya', 'kiss'],
#  ['hey',
#   'why',
#   'dont',
#   'we',
#   'just',
#   'go',
#   'watch',
#   'men',
#   'and',
#   'have',
#   'lunch',
#   'haha'],
#  ['cud',
#   'tell',
#   'ppl',
#   'im',
#   'gona',
#   'bit',
#   'co',
#   'bus',
#   'hav',
#   'gon',
#   'past',
#   'co',
#   'they',
#   'were',
#   'full',
#   'im',
#   'still',
#   'waitin',
#   'pete'],
#  ['that',
#   'would',
#   'be',
#   'great',
#   'we',
#   'll',
#   'be',
#   'at',
#   'the',
#   'guild',
#   'could',
#   'meet',
#   'on',
#   'bristol',
#   'road',
#   'or',
#   'somewhere',
#   'will',
#   'get',
#   'in',
#   'touch',
#   'over',
#   'weekend',
#   'our',
#   'plan',
#   'take',
#   'flight',
#   'have',
#   'good',
#   'week'],
#  ['no', 'problem', 'how', 'are', 'you', 'doing'],
#  ['no', 'call', 'message', 'missed', 'call'],
#  ['hi', 'da', 'how', 'is', 'the', 'today', 'class'],
#  ['say',
#   'that',
#   'good',
#   'sign',
#   'but',
#   'well',
#   'you',
#   'know',
#   'my',
#   'track',
#   'record',
#   'at',
#   'reading',
#   'woman'],
#  ['cool', 'text', 'me', 'when', 'you', 're', 'parked'],
#  ['reading',
#   'the',
#   'text',
#   'just',
#   'sent',
#   'you',
#   'it',
#   'meant',
#   'to',
#   'be',
#   'joke',
#   'so',
#   'read',
#   'it',
#   'in',
#   'that',
#   'light'],
#  ['apo', 'good', 'movie'],
#  ['maybe',
#   'could',
#   'get',
#   'book',
#   'out',
#   'tomo',
#   'then',
#   'return',
#   'it',
#   'immediately',
#   'or',
#   'something'],
#  ['call',
#   'germany',
#   'for',
#   'only',
#   'penny',
#   'per',
#   'minute',
#   'call',
#   'from',
#   'fixed',
#   'line',
#   'via',
#   'access',
#   'number',
#   'no',
#   'prepayment',
#   'direct',
#   'access'],
#  ['any',
#   'chance',
#   'you',
#   'might',
#   'have',
#   'had',
#   'with',
#   'me',
#   'evaporated',
#   'soon',
#   'you',
#   'violated',
#   'my',
#   'privacy',
#   'by',
#   'stealing',
#   'my',
#   'phone',
#   'number',
#   'from',
#   'your',
#   'employer',
#   'paperwork',
#   'not',
#   'cool',
#   'at',
#   'all',
#   'please',
#   'do',
#   'not',
#   'contact',
#   'me',
#   'again',
#   'or',
#   'will',
#   'report',
#   'you',
#   'to',
#   'your',
#   'supervisor'],
#  ['valentine',
#   'day',
#   'special',
#   'win',
#   'over',
#   'in',
#   'our',
#   'quiz',
#   'and',
#   'take',
#   'your',
#   'partner',
#   'on',
#   'the',
#   'trip',
#   'of',
#   'lifetime',
#   'send',
#   'go',
#   'to',
#   'now',
#   'msg',
#   'rcvd',
#   'custcare'],
#  ['ta', 'daaaaa', 'am', 'home', 'babe', 'are', 'you', 'still', 'up'],
#  ['cool',
#   'so',
#   'how',
#   'come',
#   'you',
#   'havent',
#   'been',
#   'wined',
#   'and',
#   'dined',
#   'before'],
#  ['just', 'sleeping', 'and', 'surfing'],
#  ['sorry', 'll', 'call', 'later'],
#  ['calling', 'me', 'right', 'call', 'my', 'hand', 'phone'],
#  ['ok', 'that', 'great', 'thanx', 'lot'],
#  ['take',
#   'it',
#   'the',
#   'post',
#   'ha',
#   'come',
#   'then',
#   'you',
#   'must',
#   'have',
#   'of',
# ...
#  ['gibbs', 'unsold', 'mike', 'hussey'],
#  ['like',
#   'to',
#   'talk',
#   'pa',
#   'but',
#   'am',
#   'not',
#   'able',
#   'to',
#   'dont',
#   'know'],
#  ['dun',
#   'cut',
#   'too',
#   'short',
#   'leh',
#   'dun',
#   'like',
#   'ah',
#   'she',
#   'failed',
#   'she',
#   'quite',
#   'sad'],
#  ['you', 'unbelievable', 'faglord'],
#  ['wife', 'how', 'she', 'knew', 'the', 'time', 'of', 'murder', 'exactly'],
#  ['why', 'do', 'you', 'ask', 'princess'],
#  ['am', 'great', 'princess', 'what', 'are', 'you', 'thinking', 'about', 'me'],
#  ['nutter',
#   'cutter',
#   'ctter',
#   'cttergg',
#   'cttargg',
#   'ctargg',
#   'ctagg',
#   'ie',
#   'you'],
#  ['it',
#   'ok',
#   'noe',
#   're',
#   'busy',
#   'but',
#   'really',
#   'too',
#   'bored',
#   'so',
#   'msg',
#   'oso',
#   'dunno',
#   'wat',
#   'colour',
#   'she',
#   'choose',
#   'me',
#   'one'],
#  ['doesn',
#   'have',
#   'class',
#   'early',
#   'tomorrow',
#   'and',
#   'thus',
#   'shouldn',
#   'be',
#   'trying',
#   'to',
#   'smoke',
#   'at',
#   'lt',
#   'gt'],
#  ['superb',
#   'thought',
#   'be',
#   'grateful',
#   'that',
#   'dont',
#   'have',
#   'everything',
#   'want',
#   'that',
#   'mean',
#   'still',
#   'have',
#   'an',
#   'opportunity',
#   'to',
#   'be',
#   'happier',
#   'tomorrow',
#   'than',
#   'are',
#   'today'],
#  ['hope', 'you', 'are', 'having', 'good', 'week', 'just', 'checking', 'in'],
#  ['used',
#   'to',
#   'it',
#   'just',
#   'hope',
#   'my',
#   'agent',
#   'don',
#   'drop',
#   'me',
#   'since',
#   've',
#   'only',
#   'booked',
#   'few',
#   'thing',
#   'this',
#   'year',
#   'this',
#   'whole',
#   'me',
#   'in',
#   'boston',
#   'them',
#   'in',
#   'nyc',
#   'wa',
#   'an',
#   'experiment'],
#  ['thursday',
#   'night',
#   'yeah',
#   'sure',
#   'thing',
#   'we',
#   'll',
#   'work',
#   'it',
#   'out',
#   'then'],
#  ['your',
#   'free',
#   'ringtone',
#   'is',
#   'waiting',
#   'to',
#   'be',
#   'collected',
#   'simply',
#   'text',
#   'the',
#   'password',
#   'mix',
#   'to',
#   'to',
#   'verify',
#   'get',
#   'usher',
#   'and',
#   'britney',
#   'fml'],
#  ['probably',
#   'money',
#   'worry',
#   'thing',
#   'are',
#   'coming',
#   'due',
#   'and',
#   'have',
#   'several',
#   'outstanding',
#   'invoice',
#   'for',
#   'work',
#   'did',
#   'two',
#   'and',
#   'three',
#   'month',
#   'ago'],
#  ['how', 'is', 'it', 'possible', 'to', 'teach', 'you', 'and', 'where'],
#  ['wonder',
#   'if',
#   'your',
#   'phone',
#   'battery',
#   'went',
#   'dead',
#   'had',
#   'to',
#   'tell',
#   'you',
#   'love',
#   'you',
#   'babe'],
#  ['lovely', 'smell', 'on', 'this', 'bus', 'and', 'it', 'ain', 'tobacco'],
#  ['we',
#   're',
#   'all',
#   'getting',
#   'worried',
#   'over',
#   'here',
#   'derek',
#   'and',
#   'taylor',
#   'have',
#   'already',
#   'assumed',
#   'the',
#   'worst'],
#  ['hey', 'what', 'up', 'charles', 'sorry', 'about', 'the', 'late', 'reply'],
#  ['all',
#   'the',
#   'lastest',
#   'from',
#   'stereophonics',
#   'marley',
#   'dizzee',
#   'racal',
#   'libertine',
#   'and',
#   'the',
#   'stroke',
#   'win',
#   'nookii',
#   'game',
#   'with',
#   'flirt',
#   'click',
#   'themob',
#   'wap',
#   'bookmark',
#   'or',
#   'text',
#   'wap',
#   'to'],
#  ['ll',
#   'give',
#   'her',
#   'once',
#   'have',
#   'it',
#   'plus',
#   'she',
#   'said',
#   'grinule',
#   'greet',
#   'you',
#   'whenever',
#   'we',
#   'speak'],
#  ['white', 'fudge', 'oreo', 'are', 'in', 'store'],
#  ['january',
#   'male',
#   'sale',
#   'hot',
#   'gay',
#   'chat',
#   'now',
#   'cheaper',
#   'call',
#   'national',
#   'rate',
#   'from',
#   'min',
#   'cheap',
#   'to',
#   'min',
#   'peak',
#   'to',
#   'stop',
#   'text',
#   'call',
#   'min'],
#  ['my',
#   'love',
#   'how',
#   'come',
#   'it',
#   'took',
#   'you',
#   'so',
#   'long',
#   'to',
#   'leave',
#   'for',
#   'zaher',
#   'got',
#   'your',
#   'word',
#   'on',
#   'ym',
#   'and',
#   'wa',
#   'happy',
#   'to',
#   'see',
#   'them',
#   'but',
#   'wa',
#   'sad',
#   'you',
#   'had',
#   'left',
#   'miss',
#   'you'],
#  ['am', 'sorry', 'it', 'hurt', 'you'],
#  ['can',
#   'feel',
#   'nauseous',
#   'so',
#   'pissed',
#   'didn',
#   'eat',
#   'any',
#   'sweet',
#   'all',
#   'week',
#   'cause',
#   'today',
#   'wa',
#   'planning',
#   'to',
#   'pig',
#   'out',
#   'wa',
#   'dieting',
#   'all',
#   'week',
#   'and',
#   'now',
#   'not',
#   'hungry'],
#  ['ok',
#   'lor',
#   'but',
#   'not',
#   'too',
#   'early',
#   'me',
#   'still',
#   'having',
#   'project',
#   'meeting',
#   'now'],
#  ['call', 'me', 'da', 'am', 'waiting', 'for', 'your', 'call'],
#  ['could',
#   'ask',
#   'carlos',
#   'if',
#   'we',
#   'could',
#   'get',
#   'more',
#   'if',
#   'anybody',
#   'else',
#   'can',
#   'chip',
#   'in'],
#  ['wa',
#   'actually',
#   'about',
#   'to',
#   'send',
#   'you',
#   'reminder',
#   'today',
#   'have',
#   'wonderful',
#   'weekend'],
#  ['when',
#   'people',
#   'see',
#   'my',
#   'msg',
#   'they',
#   'think',
#   'iam',
#   'addicted',
#   'to',
#   'msging',
#   'they',
#   'are',
#   'wrong',
#   'bcoz',
#   'they',
#   'don',
#   'know',
#   'that',
#   'iam',
#   'addicted',
#   'to',
#   'my',
#   'sweet',
#   'friend',
#   'bslvyl'],
#  ['hey',
#   'you',
#   'gave',
#   'them',
#   'your',
#   'photo',
#   'when',
#   'you',
#   'registered',
#   'for',
#   'driving',
#   'ah',
#   'tmr',
#   'wanna',
#   'meet',
#   'at',
#   'yck'],
#  ['dont', 'talk', 'to', 'him', 'ever', 'ok', 'it', 'my', 'word'],
#  ['when', 'wana', 'see', 'it', 'then'],
#  ['on',
#   'ma',
#   'way',
#   'to',
#   'school',
#   'can',
#   'you',
#   'pls',
#   'send',
#   'me',
#   'ashley',
#   'number'],
#  ['it', 'shall', 'be', 'fine', 'have', 'avalarr', 'now', 'will', 'hollalater'],
#  ['she',
#   'went',
#   'to',
#   'attend',
#   'another',
#   'two',
#   'round',
#   'today',
#   'but',
#   'still',
#   'did',
#   'reach',
#   'home'],
#  ['actually',
#   'deleted',
#   'my',
#   'old',
#   'website',
#   'now',
#   'blogging',
#   'at',
#   'magicalsongs',
#   'blogspot',
#   'com'],
#  ['wait', 'chikku', 'il', 'send', 'aftr', 'lt', 'gt', 'min'],
#  ['but',
#   'on',
#   'diet',
#   'and',
#   'ate',
#   'too',
#   'many',
#   'slice',
#   'of',
#   'pizza',
#   'yesterday',
#   'ugh',
#   'always',
#   'on',
#   'diet'],
#  ['will', 'give', 'my', 'kvb', 'acc', 'detail'],
#  ['oh', 'all', 'have', 'to', 'come', 'ah'],
#  ['money',
#   'you',
#   'lucky',
#   'winner',
#   'claim',
#   'your',
#   'prize',
#   'text',
#   'money',
#   'over',
#   'million',
#   'to',
#   'give',
#   'away',
#   'ppt',
#   'normal',
#   'text',
#   'rate',
#   'box',
#   'jy'],
#  ['really',
#   'sorry',
#   'won',
#   'able',
#   'do',
#   'this',
#   'friday',
#   'hope',
#   'can',
#   'find',
#   'an',
#   'alternative',
#   'hope',
#   'yr',
#   'term',
#   'going',
#   'ok'],
#  ['congratulation',
#   'ore',
#   'mo',
#   'owo',
#   're',
#   'wa',
#   'enjoy',
#   'it',
#   'and',
#   'wish',
#   'you',
#   'many',
#   'happy',
#   'moment',
#   'to',
#   'and',
#   'fro',
#   'wherever',
#   'you',
#   'go'],
#  ['so', 'do', 'you', 'have', 'samus', 'shoulder', 'yet'],
#  ['what',
#   'time',
#   'you',
#   'think',
#   'you',
#   'll',
#   'have',
#   'it',
#   'need',
#   'to',
#   'know',
#   'when',
#   'should',
#   'be',
#   'near',
#   'campus'],
#  ['dear',
#   'matthew',
#   'please',
#   'call',
#   'from',
#   'landline',
#   'your',
#   'complimentary',
#   'lux',
#   'tenerife',
#   'holiday',
#   'or',
#   'cash',
#   'await',
#   'collection',
#   'ppm',
#   'sae',
#   'box',
#   'sk',
#   'xh'],
#  ['then', 'dun', 'wear', 'jean', 'lor'],
#  ['since', 'when', 'which', 'side', 'any', 'fever', 'any', 'vomitin'],
#  ['are', 'you', 'in', 'college'],
#  ['urgent',
#   'call',
#   'from',
#   'landline',
#   'your',
#   'complimentary',
#   'tenerife',
#   'holiday',
#   'or',
#   'cash',
#   'await',
#   'collection',
#   'sae',
#   'box',
#   'hp',
#   'yf',
#   'ppm'],
#  ['better',
#   'made',
#   'up',
#   'for',
#   'friday',
#   'and',
#   'stuffed',
#   'myself',
#   'like',
#   'pig',
#   'yesterday',
#   'now',
#   'feel',
#   'bleh',
#   'but',
#   'at',
#   'least',
#   'it',
#   'not',
#   'writhing',
#   'pain',
#   'kind',
#   'of',
#   'bleh'],
#  ['no',
#   'we',
#   'sell',
#   'it',
#   'all',
#   'so',
#   'we',
#   'll',
#   'have',
#   'ton',
#   'if',
#   'coin',
#   'then',
#   'sell',
#   'our',
#   'coin',
#   'to',
#   'someone',
#   'thru',
#   'paypal',
#   'voila',
#   'money',
#   'back',
#   'in',
#   'life',
#   'pocket'],
#  ['theyre',
#   'doing',
#   'it',
#   'to',
#   'lot',
#   'of',
#   'place',
#   'only',
#   'hospital',
#   'and',
#   'medical',
#   'place',
#   'are',
#   'safe'],
#  ['how',
#   'about',
#   'getting',
#   'in',
#   'touch',
#   'with',
#   'folk',
#   'waiting',
#   'for',
#   'company',
#   'just',
#   'txt',
#   'back',
#   'your',
#   'name',
#   'and',
#   'age',
#   'to',
#   'opt',
#   'in',
#   'enjoy',
#   'the',
#   'community',
#   'sm'],
#  ['and',
#   'also',
#   've',
#   'sorta',
#   'blown',
#   'him',
#   'off',
#   'couple',
#   'time',
#   'recently',
#   'so',
#   'id',
#   'rather',
#   'not',
#   'text',
#   'him',
#   'out',
#   'of',
#   'the',
#   'blue',
#   'looking',
#   'for',
#   'weed'],
#  ['sent',
#   'my',
#   'score',
#   'to',
#   'sophas',
#   'and',
#   'had',
#   'to',
#   'do',
#   'secondary',
#   'application',
#   'for',
#   'few',
#   'school',
#   'think',
#   'if',
#   'you',
#   'are',
#   'thinking',
#   'of',
#   'applying',
#   'do',
#   'research',
#   'on',
#   'cost',
#   'also',
#   'contact',
#   'joke',
#   'ogunrinde',
#   'her',
#   'school',
#   'is',
#   'one',
#   'me',
#   'the',
#   'less',
#   'expensive',
#   'one'],
#  ['cant',
#   'wait',
#   'to',
#   'see',
#   'you',
#   'how',
#   'were',
#   'the',
#   'photo',
#   'were',
#   'useful'],
#  ['ur',
#   'cash',
#   'balance',
#   'is',
#   'currently',
#   'pound',
#   'to',
#   'maximize',
#   'ur',
#   'cash',
#   'in',
#   'now',
#   'send',
#   'go',
#   'to',
#   'only',
#   'msg',
#   'cc',
#   'po',
#   'box',
#   'tcr'],
#  ['hey',
#   'booked',
#   'the',
#   'kb',
#   'on',
#   'sat',
#   'already',
#   'what',
#   'other',
#   'lesson',
#   'are',
#   'we',
#   'going',
#   'for',
#   'ah',
#   'keep',
#   'your',
#   'sat',
#   'night',
#   'free',
#   'we',
#   'need',
#   'to',
#   'meet',
#   'and',
#   'confirm',
#   'our',
#   'lodging'],
#  ['chk', 'in', 'ur', 'belovd', 'dict'],
#  ['is', 'that', 'what', 'time', 'you', 'want', 'me', 'to', 'come'],
#  ['awesome', 'lemme', 'know', 'whenever', 'you', 're', 'around'],
#  ['shb', 'ok', 'lor', 'thanx'],
#  ['beautiful',
#   'truth',
#   'against',
#   'gravity',
#   'read',
#   'carefully',
#   'our',
#   'heart',
#   'feel',
#   'light',
#   'when',
#   'someone',
#   'is',
#   'in',
#   'it',
#   'but',
#   'it',
#   'feel',
#   'very',
#   'heavy',
#   'when',
#   'someone',
#   'leaf',
#   'it',
#   'good',
#   'night'],
#  ['also', 'remember', 'to', 'get', 'dobby', 'bowl', 'from', 'your', 'car'],
#  ['filthy', 'story', 'and', 'girl', 'waiting', 'for', 'your'],
#  ['sorry',
#   'now',
#   'then',
#   'ur',
#   'msg',
#   'yar',
#   'lor',
#   'so',
#   'poor',
#   'thing',
#   'but',
#   'only',
#   'one',
#   'night',
#   'tmr',
#   'll',
#   'have',
#   'brand',
#   'new',
#   'room',
#   'sleep',
#   'in'],
#  ['love',
#   'isn',
#   'decision',
#   'it',
#   'feeling',
#   'if',
#   'we',
#   'could',
#   'decide',
#   'who',
#   'to',
#   'love',
#   'then',
#   'life',
#   'would',
#   'be',
#   'much',
#   'simpler',
#   'but',
#   'then',
#   'less',
#   'magical'],
#  ['welp', 'apparently', 'he', 'retired'],
#  ['my',
#   'sort',
#   'code',
#   'is',
#   'and',
#   'acc',
#   'no',
#   'is',
#   'the',
#   'bank',
#   'is',
#   'natwest',
#   'can',
#   'you',
#   'reply',
#   'to',
#   'confirm',
#   've',
#   'sent',
#   'this',
#   'to',
#   'the',
#   'right',
#   'person'],
#  ['where'],
#  ['sure', 'can', 'take', 'any', 'sick', 'time'],
#  ['urgent',
#   'we',
#   'are',
#   'trying',
#   'to',
#   'contact',
#   'today',
#   'draw',
#   'show',
#   'that',
#   'you',
#   'have',
#   'won',
#   'prize',
#   'guaranteed',
#   'call',
#   'from',
#   'land',
#   'line',
#   'claim',
#   'valid',
#   'hr',
#   'only'],
#  ['watching',
#   'cartoon',
#   'listening',
#   'music',
#   'amp',
#   'at',
#   'eve',
#   'had',
#   'to',
#   'go',
#   'temple',
#   'amp',
#   'church',
#   'what',
#   'about'],
#  ['yo',
#   'chad',
#   'which',
#   'gymnastics',
#   'class',
#   'do',
#   'you',
#   'wanna',
#   'take',
#   'the',
#   'site',
#   'say',
#   'christian',
#   'class',
#   'is',
#   'full'],
#  ['are', 'you', 'this', 'much', 'buzy'],
#  ['or',
#   'better',
#   'still',
#   'can',
#   'you',
#   'catch',
#   'her',
#   'and',
#   'let',
#   'ask',
#   'her',
#   'if',
#   'she',
#   'can',
#   'sell',
#   'lt',
#   'gt',
#   'for',
#   'me'],
#  ['am',
#   'not',
#   'sure',
#   'about',
#   'night',
#   'menu',
#   'know',
#   'only',
#   'about',
#   'noon',
#   'menu'],
#  ['what',
#   'do',
#   'want',
#   'when',
#   'come',
#   'back',
#   'beautiful',
#   'necklace',
#   'token',
#   'of',
#   'my',
#   'heart',
#   'for',
#   'you',
#   'thats',
#   'what',
#   'will',
#   'give',
#   'but',
#   'only',
#   'to',
#   'my',
#   'wife',
#   'of',
#   'my',
#   'liking',
#   'be',
#   'that',
#   'and',
#   'see',
#   'no',
#   'one',
#   'can',
#   'give',
#   'you',
#   'that',
#   'dont',
#   'call',
#   'me',
#   'will',
#   'wait',
#   'till',
#   'come'],
#  ['are', 'you', 'willing', 'to', 'go', 'for', 'aptitude', 'class'],
#  ['it', 'wont', 'until', 'trying', 'sort', 'house', 'out', 'is', 'that', 'ok'],
#  ['yar',
#   'lor',
#   'he',
#   'wan',
#   'go',
#   'horse',
#   'racing',
#   'today',
#   'mah',
#   'so',
#   'eat',
#   'earlier',
#   'lor',
#   'ate',
#   'chicken',
#   'rice'],
#  ['haha', 'awesome', 'omw', 'back', 'now', 'then'],
#  ['yup', 'thk', 'so', 'until', 'shop', 'close', 'lor'],
#  ['what', 'is', 'your', 'account', 'number'],
#  ['eh', 'send', 'wrongly', 'lar'],
#  ['hey',
#   'no',
#   'ad',
#   'crap',
#   'nite',
#   'wa',
#   'borin',
#   'without',
#   'ya',
#   'boggy',
#   'with',
#   'me',
#   'boring',
#   'biatch',
#   'thanx',
#   'but',
#   'wait',
#   'til',
#   'nxt',
#   'time',
#   'il',
#   'ave',
#   'ya'],
#  ['ok', 'shall', 'talk', 'to', 'him'],
#  ['dont',
#   'hesitate',
#   'you',
#   'know',
#   'this',
#   'is',
#   'the',
#   'second',
#   'time',
#   'she',
#   'ha',
#   'had',
#   'weakness',
#   'like',
#   'that',
#   'so',
#   'keep',
#   'notebook',
#   'of',
#   'what',
#   'she',
#   'eat',
#   'and',
#   'did',
#   'the',
#   'day',
#   'before',
#   'or',
#   'if',
#   'anything',
#   'changed',
#   'the',
#   'day',
#   'before',
#   'so',
#   'that',
#   'we',
#   'can',
#   'be',
#   'sure',
#   'it',
#   'nothing'],
#  ['hey', 'you', 'can', 'pay', 'with', 'salary', 'de', 'only', 'lt', 'gt'],
#  ['another', 'month', 'need', 'chocolate', 'weed', 'and', 'alcohol'],
#  ['if',
#   'he',
#   'started',
#   'searching',
#   'he',
#   'will',
#   'get',
#   'job',
#   'in',
#   'few',
#   'day',
#   'he',
#   'have',
#   'great',
#   'potential',
#   'and',
#   'talent'],
#  ['reckon',
#   'need',
#   'to',
#   'be',
#   'in',
#   'town',
#   'by',
#   'eightish',
#   'to',
#   'walk',
#   'from',
#   'carpark'],
#  ['congrats',
#   'mobile',
#   'videophones',
#   'yours',
#   'call',
#   'now',
#   'videochat',
#   'wid',
#   'your',
#   'mate',
#   'play',
#   'java',
#   'game',
#   'dload',
#   'polyph',
#   'music',
#   'noline',
#   'rentl'],
#  ['look',
#   'at',
#   'the',
#   'fuckin',
#   'time',
#   'what',
#   'the',
#   'fuck',
#   'you',
#   'think',
#   'is',
#   'up'],
#  ['yo', 'guess', 'what', 'just', 'dropped'],
#  ['carlos', 'say', 'he', 'll', 'be', 'at', 'mu', 'in', 'lt', 'gt', 'minute'],
#  ['in', 'office', 'now', 'will', 'call', 'you', 'lt', 'gt', 'min'],
#  ['geeee',
#   'miss',
#   'you',
#   'already',
#   'you',
#   'know',
#   'your',
#   'all',
#   'can',
#   'think',
#   'about',
#   'fuck',
#   'can',
#   'wait',
#   'till',
#   'next',
#   'year',
#   'when',
#   'we',
#   'will',
#   'be',
#   'together',
#   'loving',
#   'kiss'],
#  ['yun',
#   'ah',
#   'the',
#   'ubi',
#   'one',
#   'say',
#   'if',
#   'wan',
#   'call',
#   'by',
#   'tomorrow',
#   'call',
#   'look',
#   'for',
#   'irene',
#   'ere',
#   'only',
#   'got',
#   'bus',
#   'ubi',
#   'cres',
#   'ubi',
#   'tech',
#   'park',
#   'ph',
#   'for',
#   'st',
#   'wkg',
#   'day'],
#  ['ugh',
#   'gotta',
#   'drive',
#   'back',
#   'to',
#   'sd',
#   'from',
#   'la',
#   'my',
#   'butt',
#   'is',
#   'sore'],
#  ['th', 'of', 'july'],
#  ['hi',
#   'im',
#   'having',
#   'the',
#   'most',
#   'relaxing',
#   'time',
#   'ever',
#   'we',
#   'have',
#   'to',
#   'get',
#   'up',
#   'at',
#   'am',
#   'every',
#   'day',
#   'wa',
#   'the',
#   'party',
#   'good',
#   'the',
#   'other',
#   'night',
#   'get',
#   'home',
#   'tomorrow',
#   'at',
#   'ish'],
#  ['up',
#   'to',
#   'wan',
#   'come',
#   'then',
#   'come',
#   'lor',
#   'but',
#   'din',
#   'any',
#   'stripe',
#   'skirt'],
#  ['the',
#   'xmas',
#   'story',
#   'is',
#   'peace',
#   'the',
#   'xmas',
#   'msg',
#   'is',
#   'love',
#   'the',
#   'xmas',
#   'miracle',
#   'is',
#   'jesus',
#   'hav',
#   'blessed',
#   'month',
#   'ahead',
#   'amp',
#   'wish',
#   'merry',
#   'xmas'],
#  ['can', 'don', 'have', 'her', 'number'],
#  ['change', 'again', 'it', 'one', 'next', 'to', 'escalator'],
#  ['yetunde',
#   'in',
#   'class',
#   'can',
#   'you',
#   'not',
#   'run',
#   'water',
#   'on',
#   'it',
#   'to',
#   'make',
#   'it',
#   'ok',
#   'pls',
#   'now'],
#  ['not',
#   'lot',
#   'ha',
#   'happened',
#   'here',
#   'feel',
#   'very',
#   'quiet',
#   'beth',
#   'is',
#   'at',
#   'her',
#   'aunt',
#   'and',
#   'charlie',
#   'is',
#   'working',
#   'lot',
#   'just',
#   'me',
#   'and',
#   'helen',
#   'in',
#   'at',
#   'the',
#   'mo',
#   'how',
#   'have',
#   'you',
#   'been'],
#  ['then',
#   'wait',
#   'me',
#   'at',
#   'bus',
#   'stop',
#   'aft',
#   'ur',
#   'lect',
#   'lar',
#   'if',
#   'dun',
#   'then',
#   'go',
#   'get',
#   'my',
#   'car',
#   'then',
#   'come',
#   'back',
#   'pick'],
#  ['aight', 'will', 'do', 'thanks', 'again', 'for', 'comin', 'out'],
#  ...]

# %% [markdown]
# ### Train Word2Vec from Scratch

# %%
model=gensim.models.Word2Vec(words,vector_size=100)

# %%
# To get all vocabulary
model.wv.index_to_key
# Out:
# ['you',
#  'to',
#  'the',
#  'and',
#  'it',
#  'in',
#  'is',
#  'me',
#  'my',
#  'for',
#  'your',
#  'call',
#  'of',
#  'that',
#  'have',
#  'on',
#  'now',
#  'are',
#  'can',
#  'so',
#  'but',
#  'not',
#  'or',
#  'we',
#  'do',
#  'get',
#  'at',
#  'be',
#  'if',
#  'will',
#  'ur',
#  'with',
#  'no',
#  'just',
#  'this',
#  'gt',
#  'lt',
#  'how',
#  'go',
#  'up',
#  'when',
#  'ok',
#  'day',
#  'what',
#  'free',
#  'from',
#  'out',
#  'all',
#  'know',
#  'll',
#  'come',
#  'like',
#  'time',
#  'good',
#  'then',
#  'am',
#  'got',
#  'wa',
#  'there',
#  'he',
#  'text',
#  'only',
#  'love',
#  'want',
#  'send',
#  'txt',
#  'need',
#  'one',
#  'today',
#  'by',
#  'going',
#  'don',
#  'home',
#  'stop',
#  'about',
#  'she',
#  'lor',
#  'sorry',
#  'see',
#  'still',
#  'mobile',
#  'take',
#  'back',
#  'da',
#  'reply',
#  'our',
#  'think',
#  'dont',
#  'tell',
#  'week',
#  'phone',
#  'hi',
#  'new',
#  'later',
#  'they',
#  'her',
#  'any',
#  'pls',
#  'ha',
#  'please',
#  'co',
#  'did',
#  'msg',
#  'been',
#  'min',
#  'some',
#  'an',
#  'make',
#  'dear',
#  'here',
#  'night',
#  'who',
#  'message',
#  'say',
#  'well',
#  're',
#  'where',
#  'thing',
#  'much',
#  'claim',
#  'great',
#  'oh',
#  'hope',
#  'hey',
#  'him',
#  'more',
#  'number',
#  'too',
#  'friend',
#  'happy',
#  'wat',
#  'give',
#  'work',
#  'had',
#  'yes',
#  'way',
#  'www',
#  've',
#  'let',
#  'prize',
#  'should',
#  'won',
#  'right',
#  'tomorrow',
#  'already',
#  'tone',
#  'after',
#  'ask',
#  'said',
#  'cash',
#  'win',
#  'doing',
#  'yeah',
#  'amp',
#  'life',
#  'really',
#  'im',
#  'meet',
#  'babe',
#  'why',
#  'find',
#  'them',
#  'very',
#  'morning',
#  'uk',
#  'thanks',
#  'year',
#  'miss',
#  'service',
#  'last',
#  'com',
#  'would',
#  'lol',
#  'also',
#  'anything',
#  'nokia',
#  'feel',
#  'care',
#  'every',
#  'pick',
#  'keep',
#  'sure',
#  'urgent',
#  'sent',
#  'over',
#  'contact',
#  'something',
#  'again',
#  'buy',
#  'before',
#  'wait',
#  'cant',
#  'first',
#  'place',
#  'help',
#  'box',
#  'went',
#  'wish',
#  'someone',
#  'nice',
#  'guy',
#  'were',
#  'even',
#  'next',
#  'which',
#  'show',
#  'word',
#  'his',
#  'around',
#  'soon',
#  'tonight',
#  'money',
#  'customer',
#  'off',
#  'could',
#  'per',
#  'sleep',
#  'chat',
#  'late',
#  'many',
#  'sm',
#  'gonna',
#  'ya',
#  'down',
#  'leave',
#  'always',
#  'name',
#  'wan',
#  'other',
#  'lot',
#  'pm',
#  'dun',
#  'gud',
#  'st',
#  'told',
#  'end',
#  'waiting',
#  'hello',
#  'hour',
#  'girl',
#  'month',
#  'fine',
#  'haha',
#  'heart',
#  'special',
#  'minute',
#  'people',
#  'coming',
#  'same',
#  'th',
#  'done',
#  'person',
#  'smile',
#  'yet',
#  'guaranteed',
#  'may',
#  'thk',
#  'getting',
#  'ppm',
#  'best',
#  'use',
#  'thought',
#  'try',
#  'offer',
#  'god',
#  'didn',
#  'class',
#  'talk',
#  'stuff',
#  'holiday',
#  'lunch',
#  'line',
#  'cost',
#  'man',
#  'mean',
#  'live',
#  'car',
#  'job',
#  'start',
#  'few',
#  'finish',
#  'draw',
#  'bit',
#  'problem',
#  'plan',
#  'house',
#  'never',
#  'meeting',
#  'hr',
#  'trying',
#  'yup',
#  'being',
#  'thats',
#  'better',
#  'ill',
#  'having',
#  'cool',
#  'rate',
#  'dat',
#  'ready',
#  'long',
#  'pobox',
#  'account',
#  'game',
#  'weekend',
#  'mind',
#  'chance',
#  'half',
#  'latest',
#  'enjoy',
#  'world',
#  'real',
#  'check',
#  'sir',
#  'than',
#  'because',
#  'room',
#  'guess',
#  'yo',
#  'wk',
#  'play',
#  'awarded',
#  'camera',
#  'look',
#  'pic',
#  'wanna',
#  'nothing',
#  'boy',
#  'eat',
#  'lar',
#  'receive',
#  'voucher',
#  'shit',
#  'liao',
#  'another',
#  'sweet',
#  'big',
#  'ah',
#  'birthday',
#  'into',
#  'po',
#  'dinner',
#  'landline',
#  'bt',
#  'video',
#  'quite',
#  'might',
#  'luv',
#  'jus',
#  'kiss',
#  'ever',
#  'age',
#  'xxx',
#  'watching',
#  'watch',
#  'question',
#  'land',
#  'probably',
#  'called',
#  'pa',
#  'bed',
#  'orange',
#  'speak',
#  'point',
#  'aight',
#  'thanx',
#  'once',
#  'nd',
#  'tv',
#  'baby',
#  'worry',
#  'fun',
#  'early',
#  'actually',
#  'sat',
#  'shall',
#  'remember',
#  'doe',
#  'nite',
#  'maybe',
#  'den',
#  'part',
#  'apply',
#  'network',
#  'ringtone',
#  'two',
#  'forgot',
#  'hear',
#  'wont',
#  'bad',
#  'princess',
#  'bus',
#  'easy',
#  'between',
#  'office',
#  'code',
#  'shopping',
#  'pay',
#  'left',
#  'dream',
#  'dunno',
#  'reach',
#  'wife',
#  'evening',
#  'fuck',
#  'face',
#  'hurt',
#  'leh',
#  'put',
#  'award',
#  'dis',
#  'dad',
#  'didnt',
#  'little',
#  'working',
#  'thank',
#  'anyway',
#  'enough',
#  'those',
#  'mail',
#  'xx',
#  'true',
#  'gift',
#  'selected',
#  'movie',
#  'everything',
#  'afternoon',
#  'yr',
#  'school',
#  'made',
#  'looking',
#  'mate',
#  'sound',
#  'while',
#  'detail',
#  'tmr',
#  'collect',
#  'asked',
#  'most',
#  'without',
#  'town',
#  'pound',
#  'missing',
#  'entry',
#  'sexy',
#  'join',
#  'since',
#  'okay',
#  'must',
#  'until',
#  'xmas',
#  'came',
#  'wif',
#  'valid',
#  'though',
#  'price',
#  'wot',
#  'collection',
#  'lesson',
#  'wake',
#  'wanted',
#  'update',
#  'run',
#  'bring',
#  'missed',
#  'hav',
#  'able',
#  'til',
#  'important',
#  'book',
#  'abt',
#  'mob',
#  'pain',
#  'answer',
#  'change',
#  'stay',
#  'juz',
#  'haven',
#  'charge',
#  'plus',
#  'test',
#  'decimal',
#  'away',
#  'de',
#  'plz',
#  'date',
#  'colour',
#  'yesterday',
#  'else',
#  'hair',
#  'alright',
#  'havent',
#  'music',
#  'attempt',
#  'dude',
#  'wen',
#  'till',
#  'weekly',
#  'saw',
#  'double',
#  'lei',
#  'food',
#  'credit',
#  'id',
#  'drink',
#  'oso',
#  'goin',
#  'optout',
#  'friendship',
#  'top',
#  'yours',
#  'haf',
#  'online',
#  'trip',
#  'bored',
#  'net',
#  'shop',
#  'making',
#  'driving',
#  'delivery',
#  'hot',
#  'national',
#  'club',
#  'feeling',
#  'ard',
#  'gr',
#  'tried',
#  'either',
#  'address',
#  'sch',
#  'family',
#  'player',
#  'yourself',
#  'coz',
#  'these',
#  'both',
#  'believe',
#  'si',
#  'mom',
#  'brother',
#  'tot',
#  'http',
#  'beautiful',
#  'story',
#  'bonus',
#  'full',
#  'sae',
#  'smoke',
#  'ring',
#  'together',
#  'second',
#  'wid',
#  'busy',
#  'post',
#  'order',
#  'head',
#  'calling',
#  'lose',
#  'nt',
#  'sad',
#  'mum',
#  'sleeping',
#  'eve',
#  'drive',
#  'huh',
#  'await',
#  'noe',
#  'leaving',
#  'saying',
#  'poly',
#  'close',
#  'smiling',
#  'set',
#  'old',
#  'chikku',
#  'happen',
#  'walk',
#  'info',
#  'row',
#  'drop',
#  'took',
#  'parent',
#  'congrats',
#  'finished',
#  'doesn',
#  'aft',
#  'hand',
#  'email',
#  'news',
#  'pub',
#  'simple',
#  'started',
#  'suite',
#  'match',
#  'awesome',
#  'mths',
#  'private',
#  'tomo',
#  'rite',
#  'thinking',
#  'hl',
#  'okie',
#  'cause',
#  'card',
#  'valentine',
#  'company',
#  'wil',
#  'break',
#  'mine',
#  'reason',
#  'content',
#  'angry',
#  'neva',
#  'caller',
#  'final',
#  'sister',
#  'forget',
#  'statement',
#  'gd',
#  'tc',
#  'auction',
#  'unsubscribe',
#  'available',
#  'tho',
#  'taking',
#  'everyone',
#  'knw',
#  'expires',
#  'anyone',
#  'lucky',
#  'search',
#  'gal',
#  'alone',
#  'whats',
#  'open',
#  'each',
#  'touch',
#  'ticket',
#  'choose',
#  'carlos',
#  'opt',
#  'whatever',
#  'loving',
#  'fancy',
#  'bank',
#  'sun',
#  'found',
#  'type',
#  'worth',
#  'dating',
#  'treat',
#  'party',
#  'identifier',
#  'secret',
#  'quiz',
#  'visit',
#  'ltd',
#  'gbp',
#  'friday',
#  'gone',
#  'uncle',
#  'song',
#  'mobileupd',
#  'frnd',
#  'decided',
#  'far',
#  'anytime',
#  'happened',
#  'hit',
#  'exam',
#  'winner',
#  'sub',
#  'congratulation',
#  'smth',
#  'welcome',
#  'boytoy',
#  'kind',
#  'fast',
#  'saturday',
#  'prob',
#  'hard',
#  'college',
#  'used',
#  'wonder',
#  'tel',
#  'light',
#  'read',
#  'lovely',
#  'crazy',
#  'mu',
#  'sea',
#  'pretty',
#  'bout',
#  'hows',
#  'chennai',
#  'oredi',
#  'goodmorning',
#  'darlin',
#  'drug',
#  'fucking',
#  'finally',
#  'wrong',
#  'operator',
#  'fri',
#  'wonderful',
#  'term',
#  'outside',
#  'wit',
#  'camcorder',
#  'nope',
#  'least',
#  'project',
#  'earlier',
#  'mrng',
#  'course',
#  'listen',
#  'ten',
#  'hmm',
#  'wasn',
#  'wq',
#  'savamob',
#  'their',
#  'case',
#  'telling',
#  'fone',
#  'meant',
#  'cum',
#  'log',
#  'blue',
#  'freemsg',
#  'frnds',
#  'unlimited',
#  'ni',
#  'hungry',
#  'cd',
#  'frm',
#  'whole',
#  'jay',
#  'isn',
#  'snow',
#  'hold',
#  'seeing',
#  'support',
#  'wkly',
#  'fr',
#  'sunday',
#  'enter',
#  'die',
#  'etc',
#  'almost',
#  'bslvyl',
#  'child',
#  'stupid',
#  'mr',
#  'hmmm',
#  'pas',
#  'download',
#  'balance',
#  'march',
#  'computer',
#  'hee',
#  'cut',
#  'move',
#  'dnt',
#  'mah',
#  'john',
#  'film',
#  'tired',
#  'joy',
#  'na',
#  'single',
#  'felt',
#  'invited',
#  'luck',
#  'side',
#  'understand',
#  'park',
#  'mayb',
#  'sk',
#  'christmas',
#  'india',
#  'reading',
#  'as',
#  'sex',
#  'rock',
#  'paper',
#  'area',
#  'within',
#  'couple',
#  'happiness',
#  'un',
#  'press',
#  'txts',
#  'valued',
#  'talking',
#  'ago',
#  'currently',
#  'yar',
#  'moment',
#  'lost',
#  'motorola',
#  'store',
#  'eh',
#  'father',
#  'gas',
#  'picking',
#  'figure',
#  'seen',
#  'gotta',
#  'redeemed',
#  'load',
#  'heard',
#  'kid',
#  'rental',
#  'darren',
#  'askd',
#  'lady',
#  'information',
#  'ish',
#  'comp',
#  'ac',
#  'ugh',
#  'met',
#  'sending',
#  'red',
#  'max',
#  'correct',
#  'supposed',
#  'laptop',
#  'reveal',
#  'direct',
#  'gym',
#  'through',
#  'extra',
#  'photo',
#  'xy',
#  'bill',
#  'grin',
#  'nyt',
#  'eye',
#  'sell',
#  'sort',
#  'ipod',
#  'semester',
#  'confirm',
#  'wow',
#  'hospital',
#  'shower',
#  'return',
#  'difficult',
#  'knew',
#  'surprise',
#  'via',
#  'swing',
#  'complimentary',
#  'promise',
#  'charged',
#  'asap',
#  'discount',
#  'member',
#  'gn',
#  'rent',
#  'whenever',
#  'lovable',
#  'monday',
#  'muz',
#  'road',
#  'bcoz',
#  'asking',
#  'slowly',
#  'slow',
#  'loved',
#  'comin',
#  'eg',
#  'blood',
#  'orchard',
#  'safe',
#  'wine',
#  'bath',
#  'link',
#  'crave',
#  'remove',
#  'study',
#  'abiola',
#  'kate',
#  'wap',
#  'clean',
#  'request',
#  'reward',
#  'lover',
#  'rest',
#  'own',
#  'save',
#  'checking',
#  'entered',
#  'page',
#  'cheer',
#  'idea',
#  'joke',
#  'loan',
#  'small',
#  'train',
#  'fantasy',
#  'wana',
#  'door',
#  'ex',
#  'leaf',
#  'txting',
#  'hg',
#  'dogging',
#  'usf',
#  'police',
#  'laugh',
#  'std',
#  'truth',
#  'somebody',
#  'rply',
#  'hmv',
#  'fact',
#  'cr',
#  'ntt',
#  'warm',
#  'glad',
#  'representative',
#  'doin',
#  'wishing',
#  'otherwise',
#  'summer',
#  'rd',
#  'la',
#  'different',
#  'il',
#  'getzed',
#  'bag',
#  'bathe',
#  'gettin',
#  'booked',
#  'water',
#  'fantastic',
#  'nah',
#  'opinion',
#  'doctor',
#  'sony',
#  'wc',
#  'across',
#  'del',
#  'hoping',
#  'sale',
#  'reached',
#  'convey',
#  'em',
#  'pray',
#  'copy',
#  'callertune',
#  'med',
#  'situation',
#  'empty',
#  'short',
#  'ho',
#  'less',
#  'gap',
#  'spend',
#  'cheap',
#  'men',
#  'gave',
#  'hw',
#  'deal',
#  'somewhere',
#  'ldn',
#  'ge',
#  'write',
#  'mm',
#  'cover',
#  'kick',
#  'admirer',
#  'yep',
#  'turn',
#  'rakhesh',
#  'merry',
#  'pete',
#  'deep',
#  'immediately',
#  'nobody',
#  'england',
#  'catch',
#  'usual',
#  'normal',
#  'woke',
#  'myself',
#  'poor',
#  'teach',
#  'custcare',
#  'bb',
#  'ringtones',
#  'voice',
#  'worried',
#  'energy',
#  'tonite',
#  'mistake',
#  'oops',
#  ...]

# %%
model.corpus_count
# Out:
# 5569

# %%
model.epochs
# Out:
# 5

# %%
model.wv.similar_by_word('good')
# Out:
# [('wa', 0.9987514615058899),
#  ('morning', 0.9986362457275391),
#  ('day', 0.9985965490341187),
#  ('happy', 0.9985893368721008),
#  ('about', 0.9984652400016785),
#  ('well', 0.9984211325645447),
#  ('night', 0.9983405470848083),
#  ('all', 0.9983283281326294),
#  ('very', 0.9983083009719849),
#  ('same', 0.9982889890670776)]

# %%
model.wv['good']
# Out:
# array([-0.27921343,  0.27407393,  0.28975052,  0.20310763,  0.14451621,
#        -0.677417  ,  0.2844815 ,  0.7838257 , -0.2713166 , -0.25750962,
#        -0.26824263, -0.6497459 , -0.13059832,  0.1597682 ,  0.21275549,
#        -0.27524504,  0.06780277, -0.46547294, -0.00509058, -0.72465736,
#         0.24483879,  0.3041009 ,  0.21512511, -0.2785855 , -0.01606855,
#         0.08972745, -0.29617676, -0.3538645 , -0.39694595, -0.02994239,
#         0.38601255,  0.05644832,  0.23986661, -0.26114184, -0.18356837,
#         0.5074632 ,  0.08571646, -0.3465934 , -0.11794188, -0.730683  ,
#         0.10921338, -0.21472296, -0.26313335,  0.05839761,  0.33264032,
#        -0.1791019 , -0.19135831, -0.09295879,  0.15113032,  0.29256478,
#         0.18997635, -0.21409096, -0.17534447,  0.02315746, -0.15526448,
#         0.16362919,  0.2242075 ,  0.1931119 , -0.4913801 ,  0.19540349,
#        -0.06030245, -0.00864466,  0.10364847, -0.15063818, -0.5193698 ,
#         0.32645884,  0.13583827,  0.25827765, -0.5081975 ,  0.42933202,
#        -0.30723092,  0.2221497 ,  0.3840495 , -0.19014454,  0.5741984 ,
#         0.15849602, -0.05584856, -0.14900745, -0.13989869,  0.08514999,
#        -0.341863  ,  0.22508094, -0.31660864,  0.45624992, -0.13152583,
#        -0.19846386,  0.23737893,  0.40734738,  0.6107735 ,  0.15254378,
#         0.3209844 ,  0.3122177 ,  0.01194808,  0.16721423,  0.61745566,
#         0.36940268,  0.21194033, -0.20140016,  0.05845734, -0.13768102],
#       dtype=float32)

# %%
model.wv['good'].shape
# Out:
# (100,)

# %%
def avg_word2vec(doc):
    return np.mean([model.wv[word] for word in doc if word in model.wv.index_to_key],axis=0)

# %%
X=[]
for i in tqdm(range(len(words))):
    X.append(avg_word2vec(words[i]))
# Out:
#   0%|          | 0/5569 [00:00<?, ?it/s]d:\Projects\MachineLearningPractice\NaturalLanguageProcessing\venv\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# d:\Projects\MachineLearningPractice\NaturalLanguageProcessing\venv\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 100%|██████████| 5569/5569 [00:00<00:00, 9533.88it/s]

# %%
X
# Out:
# [array([-0.20007722,  0.20160528,  0.19396503,  0.15541072,  0.09745434,
#         -0.47538757,  0.17012215,  0.5490614 , -0.21519718, -0.16511682,
#         -0.2093575 , -0.43636665, -0.08349514,  0.11761138,  0.14165753,
#         -0.20123258,  0.04146515, -0.34325185, -0.00324214, -0.5008009 ,
#          0.17152628,  0.18603747,  0.16118501, -0.16371669, -0.00426897,
#          0.08090473, -0.20769484, -0.23643951, -0.27133495,  0.00219051,
#          0.2599197 ,  0.02741282,  0.13890244, -0.18523486, -0.11223095,
#          0.35876507,  0.05320287, -0.24066986, -0.08198079, -0.51642734,
#        dtype=float32),
#  ...]

# %%
len(X)
# Out:
# 5569

# %% [markdown]
# ### Independent Features

# %%
X_new = np.array(X, dtype=object)

# %%
messages.shape
# Out:
# (5572, 2)

# %%
X[1]
# Out:
# array([-0.18290591,  0.17358918,  0.16347197,  0.12851383,  0.08992246,
#        -0.40625045,  0.14106399,  0.47109717, -0.18238078, -0.1481898 ,
#        -0.18107101, -0.37311128, -0.06840485,  0.1018046 ,  0.11914653,
#        -0.18387468,  0.03574204, -0.29947194, -0.00949675, -0.43516505,
#         0.15342854,  0.15832964,  0.13416615, -0.13508247, -0.00260686,
#         0.05678041, -0.18336074, -0.20553952, -0.23342042,  0.00358833,
#         0.22614671,  0.01749574,  0.10755986, -0.15833221, -0.09838893,
#         0.3045855 ,  0.03312296, -0.20288427, -0.06380151, -0.45109266,
#         0.06161053, -0.14054324, -0.17698236,  0.03339133,  0.17531875,
#        -0.11042278, -0.10225219, -0.06124637,  0.09282793,  0.17092007,
#         0.11955005, -0.16495456, -0.09679697,  0.01673869, -0.10977407,
#         0.10449005,  0.1220317 ,  0.10619886, -0.31281143,  0.13013792,
#        -0.01986147, -0.01472339,  0.07336771, -0.0799538 , -0.3182175 ,
#         0.19214424,  0.0786772 ,  0.15257886, -0.28968978,  0.28224373,
#        -0.18397084,  0.12112777,  0.2354633 , -0.12583508,  0.333563  ,
#         0.0904552 , -0.06697902, -0.06605786, -0.07172282,  0.03901615,
#        -0.19826394,  0.1181827 , -0.20295218,  0.24627618, -0.07340558,
#        -0.12047766,  0.11699061,  0.25066411,  0.3722474 ,  0.09063517,
#         0.22662625,  0.17739925, -0.00783795,  0.09734638,  0.35723576,
#         0.20150019,  0.12180723, -0.15026495,  0.01928188, -0.08015095],
#       dtype=float32)

# %%
X_new.shape
# Out:
# (5569,)

# %%
X_new[0].shape
# Out:
# (100,)

# %% [markdown]
# ### Dependent Features

# %%
# Output Features
y = messages[list(map(lambda x: len(x)>0 ,corpus))]
y=pd.get_dummies(y['label'])
y=y.iloc[:,0].values

# %%
y.shape
# Out:
# (5569,)

# %%
X[0].reshape(1,-1).shape
# Out:
# (1, 100)

# %%
# # This is the final independent features
# df = pd.DataFrame()

# for i in range(len(X)):
#     df = pd.concat([df, pd.DataFrame(X[i].reshape(1, -1))], ignore_index=True)
#     # This is the final independent features
df = pd.DataFrame([x.reshape(1, -1)[0] for x in X])

# Check the final DataFrame
print(df.head())
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.200077  0.201605  0.193965  0.155411  0.097454 -0.475388  0.170122
# 1 -0.182906  0.173589  0.163472  0.128514  0.089922 -0.406250  0.141064
# 2 -0.221289  0.206126  0.235812  0.218010  0.109153 -0.530684  0.144043
# 3 -0.288763  0.275317  0.256684  0.203615  0.135273 -0.647789  0.234489
# 4 -0.235288  0.226806  0.221812  0.161132  0.123621 -0.543085  0.199137
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.549061 -0.215197 -0.165117  ...  0.259301  0.211459 -0.010104  0.107170
# 1  0.471097 -0.182381 -0.148190  ...  0.226626  0.177399 -0.007838  0.097346
#
#          95        96        97        98        99  Output
# 0  0.238593  0.143463 -0.155768  0.019436 -0.085183    True
# 1  0.201500  0.121807 -0.150265  0.019282 -0.080151    True
# 2  0.263540  0.141514 -0.146512 -0.011659 -0.074466   False
# 3  0.316368  0.198064 -0.237109  0.028647 -0.108779    True
# 4  0.270226  0.163451 -0.204245  0.020748 -0.097352    True
#
# [5 rows x 101 columns]

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 96        0
# 97        0
# 98        0
# 99        0
# Output    0
# Length: 101, dtype: int64

# %%
## Independent Feature
X=df.drop(columns=['Output'],axis=1)

# %%
X.isnull().sum()
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 95    0
# 96    0
# 97    0
# 98    0
# 99    0
# Length: 100, dtype: int64

# %%
y=df['Output']

# %%
## Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20)

# %%
X_train.head()
# Out:
#             0         1         2         3         4         5         6   \
# 5193 -0.207724  0.188849  0.218819  0.196363  0.103176 -0.495684  0.131138
# 5447 -0.321341  0.298018  0.312987  0.269421  0.160326 -0.746890  0.219558
# 2516 -0.278613  0.291008  0.275137  0.252133  0.122419 -0.680720  0.226667
# 1586 -0.254594  0.257602  0.247571  0.167037  0.143545 -0.621922  0.233478
# 1201 -0.261085  0.261009  0.241170  0.152645  0.149641 -0.618816  0.229800
#
#             7         8         9   ...        90        91        92  \
# 5193  0.554750 -0.232659 -0.152432  ...  0.281324  0.212944 -0.018168
# 5447  0.851384 -0.354215 -0.249728  ...  0.409360  0.317569 -0.017812
# 2516  0.815862 -0.298364 -0.239791  ...  0.432368  0.304318 -0.054245
# 1586  0.727840 -0.275674 -0.243091  ...  0.332648  0.260871 -0.007753
# 1201  0.716991 -0.269276 -0.245448  ...  0.332357  0.233828 -0.019150
#
#             93        94        95        96        97        98        99
# 5193  0.105379  0.417947  0.243775  0.128868 -0.140715 -0.003294 -0.073580
# 5447  0.158290  0.646056  0.373028  0.209142 -0.231281  0.004490 -0.103326
# 2516  0.127475  0.609391  0.346323  0.168162 -0.227478 -0.026139 -0.122645
# 1586  0.145082  0.573646  0.317003  0.178402 -0.240268  0.029038 -0.102748
# 1201  0.158554  0.549025  0.303459  0.174907 -0.257441  0.021747 -0.108126
#
# [5 rows x 100 columns]

# %%
y_train
# Out:
# 5193    False
# 5447     True
# 2516     True
# 1586     True
# 1201     True
#         ...
# 4182     True
# 340      True
# 2698     True
# 4263     True
# 4554     True
# Name: Output, Length: 4445, dtype: bool

# %%
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier()

# %%
classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,classification_report
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9694244604316546

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.90      0.85      0.87       137
#         True       0.98      0.99      0.98       975
#
#     accuracy                           0.97      1112
#    macro avg       0.94      0.92      0.93      1112
# weighted avg       0.97      0.97      0.97      1112
